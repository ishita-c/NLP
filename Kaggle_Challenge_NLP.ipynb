# %% [markdown]
# # Kaggle challenge: "Bag of Words Meets Bags of Popcorn" \\
# ### Use Google's Word2Vec for movie reviews
# https://www.kaggle.com/c/word2vec-nlp-tutorial/overview

# %%
from google.colab import drive
from zipfile import ZipFile
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd 
import scipy
import torch
import numpy as np
import matplotlib.pyplot as plt
import warnings

% cd '/content/drive/MyDrive/NLP_Project/'
% ls
# Out:
# /content/drive/.shortcut-targets-by-id/1SQpROTzKCFbmaYlrRnrW_0-zIY4_859_/NLP_Project
# 300features_40minwords_10context  labeledTrainData.tsv  unlabeledTrainData.tsv
# Bag_of_Words_model.csv            testData.tsv

# %%
import pandas as pd       
train = pd.read_csv("labeledTrainData.tsv", header=0, \
                    delimiter="\t", quoting=3)

# %%
train.head() #1 positive,  0 negative review
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2  "7759_3"          0  "The film starts with a manager (Nicholas Bell...
# 3  "3630_4"          0  "It must be assumed that those who praised thi...
# 4  "9495_8"          1  "Superbly trashy and wondrously unpretentious ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         25000 non-null  object
#  1   sentiment  25000 non-null  int64
#  2   review     25000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 586.1+ KB

# %%
train.shape
# Out:
# (25000, 3)

# %%
train.columns.values
# Out:
# array(['id', 'sentiment', 'review'], dtype=object)

# %%
print(train["review"][0])
# Out:
# "With all this stuff going down at the moment with MJ i've started listening to his music, watching the odd documentary here and there, watched The Wiz and watched Moonwalker again. Maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent. Moonwalker is part biography, part feature film which i remember going to see at the cinema when it was originally released. Some of it has subtle messages about MJ's feeling towards the press and also the obvious message of drugs are bad m'kay.<br /><br />Visually impressive but of course this is all about Michael Jackson so unless you remotely like MJ in anyway then you are going to hate this and find it boring. Some may call MJ an egotist for consenting to the making of this movie BUT MJ and most of his fans would say that he made it for the fans which if true is really nice of him.<br /><br />The actual feature film bit when it finally starts is only on for 20 minutes or so excluding the Smooth Criminal sequence and Joe Pesci is convincing as a psychopathic all powerful drug lord. Why he wants MJ dead so bad is beyond me. Because MJ overheard his plans? Nah, Joe Pesci's character ranted that he wanted people to know it is he who is supplying drugs etc so i dunno, maybe he just hates MJ's music.<br /><br />Lots of cool things in this like MJ turning into a car and a robot and the whole Speed Demon sequence. Also, the director must have had the patience of a saint when it came to filming the kiddy Bad sequence as usually directors hate working with one kid let alone a whole bunch of them performing a complex dance scene.<br /><br />Bottom line, this movie is for people who like MJ on one level or another (which i think is most people). If not, then stay away. It does try and give off a wholesome message and ironically MJ's bestest buddy in this movie is a girl! Michael Jackson is truly one of the most talented people ever to grace this planet but is he guilty? Well, with all the attention i've gave this subject....hmmm well i don't know because people can be different behind closed doors, i know this for a fact. He is either an extremely nice but stupid guy or one of the most sickest liars. I hope he is not the latter."

# %%
# !pip install BeautifulSoup4
#!pip install bs4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)

# %%
# Import BeautifulSoup into your workspace
from bs4 import BeautifulSoup             

# Initialize the BeautifulSoup object on a single movie review     
example1 = BeautifulSoup(train["review"][0])  

# Print the raw review and then the output of get_text(), for 
# comparison
print(train["review"][0])
print(example1.get_text())
# Out:
# "With all this stuff going down at the moment with MJ i've started listening to his music, watching the odd documentary here and there, watched The Wiz and watched Moonwalker again. Maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent. Moonwalker is part biography, part feature film which i remember going to see at the cinema when it was originally released. Some of it has subtle messages about MJ's feeling towards the press and also the obvious message of drugs are bad m'kay.<br /><br />Visually impressive but of course this is all about Michael Jackson so unless you remotely like MJ in anyway then you are going to hate this and find it boring. Some may call MJ an egotist for consenting to the making of this movie BUT MJ and most of his fans would say that he made it for the fans which if true is really nice of him.<br /><br />The actual feature film bit when it finally starts is only on for 20 minutes or so excluding the Smooth Criminal sequence and Joe Pesci is convincing as a psychopathic all powerful drug lord. Why he wants MJ dead so bad is beyond me. Because MJ overheard his plans? Nah, Joe Pesci's character ranted that he wanted people to know it is he who is supplying drugs etc so i dunno, maybe he just hates MJ's music.<br /><br />Lots of cool things in this like MJ turning into a car and a robot and the whole Speed Demon sequence. Also, the director must have had the patience of a saint when it came to filming the kiddy Bad sequence as usually directors hate working with one kid let alone a whole bunch of them performing a complex dance scene.<br /><br />Bottom line, this movie is for people who like MJ on one level or another (which i think is most people). If not, then stay away. It does try and give off a wholesome message and ironically MJ's bestest buddy in this movie is a girl! Michael Jackson is truly one of the most talented people ever to grace this planet but is he guilty? Well, with all the attention i've gave this subject....hmmm well i don't know because people can be different behind closed doors, i know this for a fact. He is either an extremely nice but stupid guy or one of the most sickest liars. I hope he is not the latter."
# "With all this stuff going down at the moment with MJ i've started listening to his music, watching the odd documentary here and there, watched The Wiz and watched Moonwalker again. Maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent. Moonwalker is part biography, part feature film which i remember going to see at the cinema when it was originally released. Some of it has subtle messages about MJ's feeling towards the press and also the obvious message of drugs are bad m'kay.Visually impressive but of course this is all about Michael Jackson so unless you remotely like MJ in anyway then you are going to hate this and find it boring. Some may call MJ an egotist for consenting to the making of this movie BUT MJ and most of his fans would say that he made it for the fans which if true is really nice of him.The actual feature film bit when it finally starts is only on for 20 minutes or so excluding the Smooth Criminal sequence and Joe Pesci is convincing as a psychopathic all powerful drug lord. Why he wants MJ dead so bad is beyond me. Because MJ overheard his plans? Nah, Joe Pesci's character ranted that he wanted people to know it is he who is supplying drugs etc so i dunno, maybe he just hates MJ's music.Lots of cool things in this like MJ turning into a car and a robot and the whole Speed Demon sequence. Also, the director must have had the patience of a saint when it came to filming the kiddy Bad sequence as usually directors hate working with one kid let alone a whole bunch of them performing a complex dance scene.Bottom line, this movie is for people who like MJ on one level or another (which i think is most people). If not, then stay away. It does try and give off a wholesome message and ironically MJ's bestest buddy in this movie is a girl! Michael Jackson is truly one of the most talented people ever to grace this planet but is he guilty? Well, with all the attention i've gave this subject....hmmm well i don't know because people can be different behind closed doors, i know this for a fact. He is either an extremely nice but stupid guy or one of the most sickest liars. I hope he is not the latter."

# %%
import re
# Use regular expressions to do a find-and-replace
letters_only = re.sub("[^a-zA-Z]",           # The pattern to search for
                      " ",                   # The pattern to replace it with
                      example1.get_text() )  # The text to search
print(letters_only)
# Out:
#  With all this stuff going down at the moment with MJ i ve started listening to his music  watching the odd documentary here and there  watched The Wiz and watched Moonwalker again  Maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent  Moonwalker is part biography  part feature film which i remember going to see at the cinema when it was originally released  Some of it has subtle messages about MJ s feeling towards the press and also the obvious message of drugs are bad m kay Visually impressive but of course this is all about Michael Jackson so unless you remotely like MJ in anyway then you are going to hate this and find it boring  Some may call MJ an egotist for consenting to the making of this movie BUT MJ and most of his fans would say that he made it for the fans which if true is really nice of him The actual feature film bit when it finally starts is only on for    minutes or so excluding the Smooth Criminal sequence and Joe Pesci is convincing as a psychopathic all powerful drug lord  Why he wants MJ dead so bad is beyond me  Because MJ overheard his plans  Nah  Joe Pesci s character ranted that he wanted people to know it is he who is supplying drugs etc so i dunno  maybe he just hates MJ s music Lots of cool things in this like MJ turning into a car and a robot and the whole Speed Demon sequence  Also  the director must have had the patience of a saint when it came to filming the kiddy Bad sequence as usually directors hate working with one kid let alone a whole bunch of them performing a complex dance scene Bottom line  this movie is for people who like MJ on one level or another  which i think is most people   If not  then stay away  It does try and give off a wholesome message and ironically MJ s bestest buddy in this movie is a girl  Michael Jackson is truly one of the most talented people ever to grace this planet but is he guilty  Well  with all the attention i ve gave this subject    hmmm well i don t know because people can be different behind closed doors  i know this for a fact  He is either an extremely nice but stupid guy or one of the most sickest liars  I hope he is not the latter

# %%
lower_case = letters_only.lower()        # Convert to lower case
words = lower_case.split()               # Split into words

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')   # Download text data sets, including stop words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
f
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Remove stop words from "words"
words = [w for w in words if not w in stopwords.words("english")]
print(words)
# Out:
# ['stuff', 'going', 'moment', 'mj', 'started', 'listening', 'music', 'watching', 'odd', 'documentary', 'watched', 'wiz', 'watched', 'moonwalker', 'maybe', 'want', 'get', 'certain', 'insight', 'guy', 'thought', 'really', 'cool', 'eighties', 'maybe', 'make', 'mind', 'whether', 'guilty', 'innocent', 'moonwalker', 'part', 'biography', 'part', 'feature', 'film', 'remember', 'going', 'see', 'cinema', 'originally', 'released', 'subtle', 'messages', 'mj', 'feeling', 'towards', 'press', 'also', 'obvious', 'message', 'drugs', 'bad', 'kay', 'visually', 'impressive', 'course', 'michael', 'jackson', 'unless', 'remotely', 'like', 'mj', 'anyway', 'going', 'hate', 'find', 'boring', 'may', 'call', 'mj', 'egotist', 'consenting', 'making', 'movie', 'mj', 'fans', 'would', 'say', 'made', 'fans', 'true', 'really', 'nice', 'actual', 'feature', 'film', 'bit', 'finally', 'starts', 'minutes', 'excluding', 'smooth', 'criminal', 'sequence', 'joe', 'pesci', 'convincing', 'psychopathic', 'powerful', 'drug', 'lord', 'wants', 'mj', 'dead', 'bad', 'beyond', 'mj', 'overheard', 'plans', 'nah', 'joe', 'pesci', 'character', 'ranted', 'wanted', 'people', 'know', 'supplying', 'drugs', 'etc', 'dunno', 'maybe', 'hates', 'mj', 'music', 'lots', 'cool', 'things', 'like', 'mj', 'turning', 'car', 'robot', 'whole', 'speed', 'demon', 'sequence', 'also', 'director', 'must', 'patience', 'saint', 'came', 'filming', 'kiddy', 'bad', 'sequence', 'usually', 'directors', 'hate', 'working', 'one', 'kid', 'let', 'alone', 'whole', 'bunch', 'performing', 'complex', 'dance', 'scene', 'bottom', 'line', 'movie', 'people', 'like', 'mj', 'one', 'level', 'another', 'think', 'people', 'stay', 'away', 'try', 'give', 'wholesome', 'message', 'ironically', 'mj', 'bestest', 'buddy', 'movie', 'girl', 'michael', 'jackson', 'truly', 'one', 'talented', 'people', 'ever', 'grace', 'planet', 'guilty', 'well', 'attention', 'gave', 'subject', 'hmmm', 'well', 'know', 'people', 'different', 'behind', 'closed', 'doors', 'know', 'fact', 'either', 'extremely', 'nice', 'stupid', 'guy', 'one', 'sickest', 'liars', 'hope', 'latter']

# %%
def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
  clean_review = review_to_words( train["review"][0] )
  print(clean_review)
# Out:
# stuff going moment mj started listening music watching odd documentary watched wiz watched moonwalker maybe want get certain insight guy thought really cool eighties maybe make mind whether guilty innocent moonwalker part biography part feature film remember going see cinema originally released subtle messages mj feeling towards press also obvious message drugs bad kay visually impressive course michael jackson unless remotely like mj anyway going hate find boring may call mj egotist consenting making movie mj fans would say made fans true really nice actual feature film bit finally starts minutes excluding smooth criminal sequence joe pesci convincing psychopathic powerful drug lord wants mj dead bad beyond mj overheard plans nah joe pesci character ranted wanted people know supplying drugs etc dunno maybe hates mj music lots cool things like mj turning car robot whole speed demon sequence also director must patience saint came filming kiddy bad sequence usually directors hate working one kid let alone whole bunch performing complex dance scene bottom line movie people like mj one level another think people stay away try give wholesome message ironically mj bestest buddy movie girl michael jackson truly one talented people ever grace planet guilty well attention gave subject hmmm well know people different behind closed doors know fact either extremely nice stupid guy one sickest liars hope latter

# %%
# Get the number of reviews based on the dataframe column size
num_reviews = train["review"].size

# Initialize an empty list to hold the clean reviews
clean_train_reviews = []

# Loop over each review; create an index i that goes from 0 to the length
# of the movie review list 
xrange=range
for i in xrange (0, num_reviews):
    # Call our function for each one, and add the result to the list of
    # clean reviews
    clean_train_reviews.append( review_to_words( train["review"][i] ) )

print(f'num_reviews: {num_reviews}')
# Out:
# num_reviews: 25000

# %%
print("Cleaning and parsing the training set movie reviews...\n")
clean_train_reviews = []
for i in xrange( 0, num_reviews ):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print("Review %d of %d\n" % ( i+1, num_reviews ))                                                                
    clean_train_reviews.append( review_to_words( train["review"][i] ))
# Out:
# Cleaning and parsing the training set movie reviews...
#
# Review 1000 of 25000
#
# Review 2000 of 25000
#
# Review 3000 of 25000
#
# Review 4000 of 25000
#
# Review 5000 of 25000
#
# Review 6000 of 25000
#
# Review 7000 of 25000
#
# Review 8000 of 25000
#
# Review 9000 of 25000
#
# Review 10000 of 25000
#
# Review 11000 of 25000
#
# Review 12000 of 25000
#
# Review 13000 of 25000
#
# Review 14000 of 25000
#
# Review 15000 of 25000
#
# Review 16000 of 25000
#
# Review 17000 of 25000
#
# Review 18000 of 25000
#
# Review 19000 of 25000
#
# Review 20000 of 25000
#
# Review 21000 of 25000
#
# Review 22000 of 25000
#
# Review 23000 of 25000
#
# Review 24000 of 25000
#
# Review 25000 of 25000

# %%
print("Creating the bag of words...\n")
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(clean_train_reviews)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()
# Out:
# Creating the bag of words...

# %%
print(train_data_features.shape)
# Out:
# (25000, 5000)

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print(vocab)
# Out:
# ['abandoned', 'abc', 'abilities', 'ability', 'able', 'abraham', 'absence', 'absent', 'absolute', 'absolutely', 'absurd', 'abuse', 'abusive', 'abysmal', 'academy', 'accent', 'accents', 'accept', 'acceptable', 'accepted', 'access', 'accident', 'accidentally', 'accompanied', 'accomplished', 'according', 'account', 'accuracy', 'accurate', 'accused', 'achieve', 'achieved', 'achievement', 'acid', 'across', 'act', 'acted', 'acting', 'action', 'actions', 'activities', 'actor', 'actors', 'actress', 'actresses', 'acts', 'actual', 'actually', 'ad', 'adam', 'adams', 'adaptation', 'adaptations', 'adapted', 'add', 'added', 'adding', 'addition', 'adds', 'adequate', 'admire', 'admit', 'admittedly', 'adorable', 'adult', 'adults', 'advance', 'advanced', 'advantage', 'adventure', 'adventures', 'advertising', 'advice', 'advise', 'affair', 'affect', 'affected', 'afford', 'aforementioned', 'afraid', 'africa', 'african', 'afternoon', 'afterwards', 'age', 'aged', 'agent', 'agents', 'ages', 'aging', 'ago', 'agree', 'agreed', 'agrees', 'ah', 'ahead', 'aid', 'aids', 'aim', 'aimed', 'air', 'aired', 'airplane', 'airport', 'aka', 'akshay', 'al', 'alan', 'alas', 'albeit', 'albert', 'album', 'alcohol', 'alcoholic', 'alec', 'alert', 'alex', 'alexander', 'alfred', 'alice', 'alicia', 'alien', 'aliens', 'alike', 'alison', 'alive', 'allen', 'allow', 'allowed', 'allowing', 'allows', 'almost', 'alone', 'along', 'alongside', 'already', 'alright', 'also', 'alternate', 'alternative', 'although', 'altman', 'altogether', 'always', 'amanda', 'amateur', 'amateurish', 'amazed', 'amazing', 'amazingly', 'ambiguous', 'ambitious', 'america', 'american', 'americans', 'amitabh', 'among', 'amongst', 'amount', 'amounts', 'amused', 'amusing', 'amy', 'analysis', 'ancient', 'anderson', 'andre', 'andrew', 'andrews', 'andy', 'angel', 'angela', 'angeles', 'angels', 'anger', 'angle', 'angles', 'angry', 'animal', 'animals', 'animated', 'animation', 'anime', 'ann', 'anna', 'anne', 'annie', 'annoyed', 'annoying', 'another', 'answer', 'answers', 'anthony', 'anti', 'antics', 'antonioni', 'antwone', 'anybody', 'anymore', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'apart', 'apartment', 'ape', 'apes', 'appalling', 'apparent', 'apparently', 'appeal', 'appealing', 'appear', 'appearance', 'appearances', 'appeared', 'appearing', 'appears', 'appreciate', 'appreciated', 'appreciation', 'approach', 'appropriate', 'april', 'area', 'areas', 'arguably', 'argue', 'argument', 'arm', 'armed', 'arms', 'army', 'arnold', 'around', 'arrested', 'arrival', 'arrive', 'arrived', 'arrives', 'arrogant', 'art', 'arthur', 'artificial', 'artist', 'artistic', 'artists', 'arts', 'ashamed', 'ashley', 'asian', 'aside', 'ask', 'asked', 'asking', 'asks', 'asleep', 'aspect', 'aspects', 'ass', 'assassin', 'assault', 'assigned', 'assistant', 'associated', 'assume', 'assumed', 'astaire', 'astonishing', 'atlantis', 'atmosphere', 'atmospheric', 'atrocious', 'attached', 'attack', 'attacked', 'attacks', 'attempt', 'attempted', 'attempting', 'attempts', 'attend', 'attention', 'attitude', 'attitudes', 'attorney', 'attracted', 'attraction', 'attractive', 'audience', 'audiences', 'audio', 'aunt', 'austen', 'austin', 'australia', 'australian', 'authentic', 'author', 'authority', 'available', 'average', 'avoid', 'avoided', 'awake', 'award', 'awards', 'aware', 'away', 'awe', 'awesome', 'awful', 'awfully', 'awhile', 'awkward', 'babe', 'baby', 'bacall', 'back', 'backdrop', 'background', 'backgrounds', 'bad', 'badly', 'bag', 'baker', 'bakshi', 'balance', 'baldwin', 'ball', 'ballet', 'balls', 'band', 'bands', 'bang', 'bank', 'banned', 'bar', 'barbara', 'bare', 'barely', 'bargain', 'barry', 'barrymore', 'base', 'baseball', 'based', 'basement', 'basic', 'basically', 'basis', 'basketball', 'bat', 'bath', 'bathroom', 'batman', 'battle', 'battles', 'bay', 'bbc', 'beach', 'bear', 'bears', 'beast', 'beat', 'beaten', 'beating', 'beats', 'beatty', 'beautiful', 'beautifully', 'beauty', 'became', 'become', 'becomes', 'becoming', 'bed', 'bedroom ...
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
import numpy as np

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print(f'values: {count}, {tag}')
# Out:
# values: 187, abandoned
# values: 125, abc
# values: 108, abilities
# values: 454, ability
# values: 1259, able
# values: 85, abraham
# values: 116, absence
# values: 83, absent
# values: 352, absolute
# values: 1485, absolutely
# values: 306, absurd
# values: 192, abuse
# values: 91, abusive
# values: 98, abysmal
# values: 297, academy
# values: 485, accent
# values: 203, accents
# values: 300, accept
# values: 130, acceptable
# values: 144, accepted
# values: 92, access
# values: 318, accident
# values: 200, accidentally
# values: 88, accompanied
# values: 124, accomplished
# values: 296, according
# values: 186, account
# values: 81, accuracy
# values: 284, accurate
# values: 123, accused
# values: 179, achieve
# values: 139, achieved
# values: 124, achievement
# values: 90, acid
# values: 971, across
# values: 1251, act
# values: 658, acted
# values: 6490, acting
# values: 3354, action
# values: 311, actions
# values: 83, activities
# values: 2389, actor
# values: 4486, actors
# values: 1219, actress
# values: 369, actresses
# values: 394, acts
# values: 793, actual
# values: 4237, actually
# values: 148, ad
# values: 302, adam
# values: 98, adams
# values: 453, adaptation
# values: 80, adaptations
# values: 154, adapted
# values: 810, add
# values: 439, added
# values: 166, adding
# values: 347, addition
# values: 337, adds
# values: 113, adequate
# values: 124, admire
# values: 621, admit
# values: 134, admittedly
# values: 101, adorable
# values: 510, adult
# values: 376, adults
# values: 100, advance
# values: 90, advanced
# values: 153, advantage
# values: 510, adventure
# values: 204, adventures
# values: 91, advertising
# values: 259, advice
# values: 90, advise
# values: 346, affair
# values: 93, affect
# values: 113, affected
# values: 104, afford
# values: 126, aforementioned
# values: 343, afraid
# values: 212, africa
# values: 255, african
# values: 187, afternoon
# values: 128, afterwards
# values: 1121, age
# values: 233, aged
# values: 361, agent
# values: 94, agents
# values: 249, ages
# values: 111, aging
# values: 1033, ago
# values: 572, agree
# values: 88, agreed
# values: 96, agrees
# values: 119, ah
# values: 396, ahead
# values: 106, aid
# values: 96, aids
# values: 81, aim
# values: 120, aimed
# values: 639, air
# values: 146, aired
# values: 92, airplane
# values: 93, airport
# values: 194, aka
# values: 100, akshay
# values: 376, al
# values: 351, alan
# values: 163, alas
# values: 157, albeit
# values: 265, albert
# values: 84, album
# values: 84, alcohol
# values: 93, alcoholic
# values: 81, alec
# values: 94, alert
# values: 231, alex
# values: 121, alexander
# values: 85, alfred
# values: 199, alice
# values: 79, alicia
# values: 373, alien
# values: 199, aliens
# values: 152, alike
# values: 86, alison
# values: 463, alive
# values: 407, allen
# values: 308, allow
# values: 325, allowed
# values: 128, allowing
# values: 252, allows
# values: 3139, almost
# values: 1061, alone
# values: 1776, along
# values: 90, alongside
# values: 1381, already
# values: 185, alright
# values: 9156, also
# values: 88, alternate
# values: 78, alternative
# values: 2537, although
# values: 114, altman
# values: 112, altogether
# values: 3239, always
# values: 101, amanda
# values: 215, amateur
# values: 216, amateurish
# values: 183, amazed
# values: 1320, amazing
# values: 174, amazingly
# values: 80, ambiguous
# values: 126, ambitious
# values: 728, america
# values: 2228, american
# values: 365, americans
# values: 92, amitabh
# values: 783, among
# values: 160, amongst
# values: 495, amount
# values: 90, amounts
# values: 78, amused
# values: 509, amusing
# values: 104, amy
# values: 88, analysis
# values: 233, ancient
# values: 223, anderson
# values: 79, andre
# values: 147, andrew
# values: 151, andrews
# values: 318, andy
# values: 230, angel
# values: 85, angela
# values: 101, angeles
# values: 161, angels
# values: 191, anger
# values: 185, angle
# values: 206, angles
# values: 336, angry
# values: 342, animal
# values: 410, animals
# values: 516, animated
# values: 826, animation
# values: 240, anime
# values: 288, ann
# values: 251, anna
# values: 254, anne
# values: 117, annie
# values: 143, annoyed
# values: 998, annoying
# values: 4325, another
# values: 361, answer
# values: 176, answers
# values: 263, anthony
# values: 480, anti
# values: 113, antics
# values: 82, antonioni
# values: 88, antwone
# values: 310, anybody
# values: 333, anymore
# values: 2630, anyone
# values: 2949, anything
# values: 1117, anyway
# values: 113, anyways
# values: 304, anywhere
# values: 623, apart
# values: 339, apartment
# values: 105, ape
# values: 113, apes
# values: 125, appalling
# values: 309, apparent
# values: 917, apparently
# values: 448, appeal
# values: 225, appealing
# values: 619, appear
# values: 451, appearance
# values: 139, appearances
# values: 371, appeared
# values: 141, appearing
# values: 841, appears
# values: 507, appreciate
# values: 196, appreciated
# values: 88, appreciation
# values: 372, approach
# values: 221, appropriate
# values: 101, april
# values: 337, area
# values: 116, areas
# values: 90, arguably
# values: 111, argue
# values: 118, argument
# values: 152, arm
# values: 95, armed
# values: 175, arms
# values: 454, army
# values: 148, arnold
# values: 3616, around
# values: 126, arrested
# values: 87, arrival
# values: 114, arrive
# values: 93, arrived
# values: 162, arrives
# values: 99, arrogant
# values: 1293, art
# values: 373, arthur
# values: 94, artificial
# values: 331, artist
# values: 339, artistic
# values: 182, artists
# values: 310, arts
# values: 158, ashamed
# values: 89, ashley
# values: 237, asian
# values: 473, aside
# values: 648, ask
# values: 295, asked
# values: 228, asking
# values: 329, asks
# values: 213, asleep
# values: 454, aspect
# values: 398, aspects
# values: 267, ass
# values: 85, assassin
# values: 88, assault
# values: 83, assigned
# values: 148, assistant
# values: 131, associated
# values: 229, assume
# values: 82, assumed
# values: 132, astaire
# values: 79, astonishing
# values: 111, atlantis
# values: 735, atmosphere
# values: 148, atmospheric
# values: 197, atrocious
# values: 132, attached
# values: 449, attack
# values: 158, attacked
# values: 158, attacks
# values: 1050, attempt
# values: 136, attempted
# values: 163, attempting
# values: 583, attempts
# values: 83, attend
# values: 906, attention
# values: 237, attitude
# values: 90, attitudes
# values: 89, attorney
# values: 123, attracted
# values: 143, attraction
# values: 352, attractive
# values: 2199, audience
# values: 476, audiences
# values: 113, audio
# values: 173, aunt
# values: 91, austen
# values: 82, austin
# values: 126, australia
# values: 206, australian
# values: 166, authentic
# values: 275, author
# values: 101, authority
# values: 388, available
# values: 720, average
# values: 775, avoid
# values: 102, avoided
# values: 106, awake
# values: 419, award
# values: 245, awards
# values: 277, aware
# values: 2775, away
# values: 101, awe
# values: 485, awesome
# values: 1724, awful
# values: 84, awfully
# values: 78, awhile
# values: 248, awkward
# values: 100, babe
# values: 693, baby
# values: 90, bacall
# values: 4972, back
# values: 105, backdrop
# values: 619, background
# values: 101, backgrounds
# values: 9301, bad
# values: 662, badly
# values: 150, bag
# values: 155, baker
# values: 130, bakshi
# values: 161, balance
# values: 80, baldwin
# values: 290, ball
# values: 94, ballet
# values: 93, balls
# values: 529, band
# values: 93, bands
# values: 108, bang
# values: 265, bank
# values: 108, banned
# values: 387, bar
# values: 243, barbara
# values: 114, bare
# values: 483, barely
# values: 86, bargain
# values: 134, barry
# values: 88, barrymore
# values: 173, base
# values: 215, baseball
# values: 1430, based
# values: 143, basement
# values: 519, basic
# values: 906, basically
# values: 169, basis
# values: 88, basketball
# values: 168, bat
# values: 93, bath
# values: 114, bathroom
# values: 432, batman
# values: 614, battle
# values: 136, battles
# values: 89, bay
# values: 189, bbc
# values: 191, beach
# values: 251, bear
# values: 140, bears
# values: 187, beast
# values: 354, beat
# values: 124, beaten
# values: 138, beating
# values: 111, beats
# values: 113, beatty
# values: 2177, beautiful
# values: 436, beautifully
# values: 655, beauty
# values: 697, became
# values: 1544, become
# values: 1380, becomes
# values: 348, becoming
# values: 384, bed
# values: 107, bedroom
# values: 123, beer
# values: 318, began
# values: 678, begin
# values: 1401, beginning
# values: 795, begins
# values: 94, behave
# values: 261, behavior
# values: 1280, behind
# values: 128, beings
# values: 94, bela
# values: 188, belief
# values: 92, beliefs
# values: 711, believable
# values: 2505, believe
# values: 208, believed
# values: 228, believes
# values: 137, believing
# values: 112, bell
# values: 85, belong
# values: 142, belongs
# values: 178, beloved
# values: 87, belushi
# values: 616, ben
# values: 104, beneath
# values: 102, benefit
# values: 96, bergman
# values: 99, berlin
# values: 410, besides
# values: 6416, best
# values: 244, bet
# values: 155, bette
# values: 5737, better
# values: 163, bettie
# values: 89, betty
# values: 866, beyond
# values: 134, bible
# values: 3477, big
# values: 268, bigger
# values: 515, biggest
# values: 89, biko
# values: 633, bill
# values: 79, billed
# values: 375, billy
# values: 110, bin
# values: 82, biography
# values: 113, bird
# values: 116, birds
# values: 196, birth
# values: 137, birthday
# values: 3054, bit
# values: 114, bite
# values: 295, bits
# values: 164, bitter
# values: 499, bizarre
# values: 2033, black
# values: 95, blade
# values: 195, blah
# values: 167, blair
# values: 110, blake
# values: 290, blame
# values: 273, bland
# values: 122, blank
# values: 79, blast
# values: 104, blatant
# values: 119, bleak
# values: 113, blend
# values: 101, blew
# values: 262, blind
# values: 122, blob
# values: 113, block
# values: 187, blockbuster
# values: 97, blond
# values: 270, blonde
# values: 1185, blood
# values: 302, bloody
# values: 202, blow
# values: 108, blowing
# values: 184, blown
# values: 122, blows
# values: 431, blue
# values: 100, blues
# values: 94, blunt
# values: 156, bo
# values: 250, board
# values: 254, boat
# values: 266, bob
# values: 138, bobby
# values: 217, bodies
# values: 972, body
# values: 102, bold
# values: 143, boll
# values: 169, bollywood
# values: 235, bomb
# values: 340, bond
# values: 114, bone
# values: 97, bonus
# values: 2421, book
# values: 505, books
# values: 93, boom
# values: 95, boot
# values: 124, border
# values: 181, bore
# values: 530, bored
# values: 141, boredom
# values: 1809, boring
# values: 385, born
# values: 84, borrowed
# values: 415, boss
# values: 395, bother
# values: 187, bothered
# values: 91, bottle
# values: 421, bottom
# values: 458, bought
# values: 179, bound
# values: 190, bourne
# values: 637, box
# values: 126, boxing
# values: 1560, boy
# values: 399, boyfriend
# values: 79, boyle
# values: 618, boys
# values: 175, brad
# values: 109, brady
# values: 474, brain
# values: 109, brains
# values: 186, branagh
# values: 135, brand
# values: 158, brando
# values: 202, brave
# values: 116, brazil
# values: 611, break
# values: 231, breaking
# values: 259, breaks
# values: 128, breasts
# values: 177, breath
# values: 168, breathtaking
# values: 84, brenda
# values: 352, brian
# values: 136, bride
# values: 157, bridge
# values: 395, brief
# values: 135, briefly
# values: 273, bright
# values: 129, brilliance
# values: 1195, brilliant
# values: 248, brilliantly
# values: 869, bring
# values: 216, bringing
# values: 630, brings
# values: 149, britain
# values: 898, british
# values: 115, broad
# values: 114, broadcast
# values: 242, broadway
# values: 151, broke
# values: 278, broken
# values: 105, brooklyn
# values: 169, brooks
# values: 128, brosnan
# values: 1107, brother
# values: 557, brothers
# values: 737, brought
# values: 271, brown
# values: 393, bruce
# values: 303, brutal
# values: 81, brutality
# values: 90, brutally
# values: 175, buck
# values: 124, bucks
# values: 83, bud
# values: 109, buddies
# values: 258, buddy
# values: 1836, budget
# values: 102, buff
# values: 82, buffalo
# values: 98, buffs
# values: 119, bug
# values: 152, bugs
# values: 318, build
# values: 395, building
# values: 94, buildings
# values: 114, builds
# values: 236, built
# values: 102, bull
# values: 109, bullet
# values: 124, bullets
# values: 85, bumbling
# values: 813, bunch
# values: 78, bunny
# values: 126, buried
# values: 127, burn
# values: 114, burned
# values: 144, burning
# values: 183, burns
# values: 167, burt
# values: 152, burton
# values: 186, bus
# values: 136, bush
# values: 624, business
# values: 83, businessman
# values: 81, buster
# values: 162, busy
# values: 86, butler
# values: 123, butt
# values: 96, button
# values: 763, buy
# values: 184, buying
# values: 175, cabin
# values: 279, cable
# values: 296, cage
# values: 124, cagney
# values: 204, caine
# values: 98, cake
# values: 84, caliber
# values: 189, california
# values: 923, call
# values: 1433, called
# values: 176, calling
# values: 260, calls
# values: 86, calm
# values: 1673, came
# values: 259, cameo
# values: 146, cameos
# values: 1778, camera
# values: 110, cameras
# values: 123, cameron
# values: 463, camp
# values: 97, campbell
# values: 179, campy
# values: 139, canada
# values: 226, canadian
# values: 289, candy
# values: 84, cannibal
# values: 1096, cannot
# values: 202, cant
# values: 228, capable
# values: 89, capital
# values: 326, captain
# values: 119, captivating
# values: 287, capture
# values: 261, captured
# values: 216, captures
# values: 88, capturing
# values: 1225, car
# values: 150, card
# values: 131, cardboard
# values: 99, cards
# values: 1385, care
# values: 121, cared
# values: 1007, career
# values: 107, careers
# values: 90, careful
# values: 134, carefully
# values: 88, carell
# values: 228, cares
# values: 166, caring
# values: 109, carl
# values: 85, carla
# values: 138, carol
# values: 161, carpenter
# values: 94, carradine
# values: 131, carrey
# values: 117, carrie
# values: 163, carried
# values: 163, carries
# values: 326, carry
# values: 165, carrying
# values: 279, cars
# values: 151, carter
# values: 545, cartoon
# values: 205, cartoons
# values: 108, cary
# values: 1533, case
# values: 163, cases
# values: 236, cash
# values: 85, cassidy
# values: 3829, cast
# values: 622, casting
# values: 339, castle
# values: 547, cat
# values: 447, catch
# values: 106, catches
# values: 92, catching
# values: 91, catchy
# values: 211, category
# values: 142, catherine
# values: 152, catholic
# values: 110, cats
# values: 555, caught
# values: 534, cause
# values: 237, caused
# values: 166, causes
# values: 107, causing
# values: 98, cave
# values: 97, cd
# values: 102, celebrity
# values: 176, cell
# values: 107, celluloid
# values: 232, center
# values: 109, centered
# values: 91, centers
# values: 411, central
# values: 528, century
# values: 764, certain
# values: 1462, certainly
# values: 96, cg
# values: 325, cgi
# values: 122, chain
# values: 157, chair
# values: 165, challenge
# values: 88, challenging
# values: 81, championship
# values: 207, chan
# values: 1067, chance
# values: 133, chances
# values: 959, change
# values: 484, changed
# values: 386, changes
# values: 194, changing
# values: 442, channel
# values: 86, channels
# values: 105, chaos
# values: 150, chaplin
# values: 88, chapter
# values: 7023, character
# values: 123, characterization
# values: 7154, characters
# values: 168, charge
# values: 138, charisma
# values: 135, charismatic
# values: 408, charles
# values: 439, charlie
# values: 98, charlotte
# values: 407, charm
# values: 471, charming
# values: 438, chase
# values: 98, chased
# values: 143, chases
# values: 145, chasing
# values: 217, che
# values: 892, cheap
# values: 92, cheated
# values: 103, cheating
# values: 762, check
# values: 80, checked
# values: 139, checking
# values: 114, cheek
# values: 158, cheese
# values: 634, cheesy
# values: 490, chemistry
# values: 96, chess
# values: 93, chest
# values: 92, chicago
# values: 233, chick
# values: 80, chicken
# values: 89, chicks
# values: 229, chief
# values: 1320, child
# values: 356, childhood
# values: 117, childish
# values: 1510, children
# values: 169, chilling
# values: 188, china
# values: 337, chinese
# values: 528, choice
# values: 171, choices
# values: 227, choose
# values: 85, chooses
# values: 99, choreographed
# values: 115, choreography
# values: 99, chorus
# values: 202, chose
# values: 232, chosen
# values: 421, chris
# values: 183, christ
# values: 373, christian
# values: 79, christianity
# values: 92, christians
# values: 623, christmas
# values: 415, christopher
# values: 97, christy
# values: 142, chuck
# values: 406, church
# values: 123, cia
# values: 233, cinderella
# values: 1491, cinema
# values: 412, cinematic
# values: 101, cinematographer
# values: 983, cinematography
# values: 103, circle
# values: 218, circumstances
# values: 88, cities
# values: 125, citizen
# values: 1195, city
# values: 140, civil
# values: 93, civilization
# values: 222, claim
# values: 100, claimed
# values: 205, claims
# values: 173, claire
# values: 204, clark
# values: 893, class
# values: 106, classes
# values: 1828, classic
# values: 88, classical
# values: 233, classics
# values: 80, claus
# values: 243, clean
# values: 786, clear
# values: 899, clearly
# values: 533, clever
# values: 94, cleverly
# values: 840, clich
# values: 96, cliche
# values: 112, cliff
# values: 93, climactic
# values: 422, climax
# values: 110, clint
# values: 83, clip
# values: 162, clips
# values: 96, clock
# values: 1296, close
# values: 92, closed
# values: 140, closely
# values: 206, closer
# values: 94, closest
# values: 103, closet
# values: 177, closing
# values: 328, clothes
# values: 110, clothing
# values: 107, clown
# values: 434, club
# values: 224, clue
# values: 123, clues
# values: 105, clumsy
# values: 604, co
# values: 102, coach
# values: 80, coast
# values: 241, code
# values: 106, coffee
# values: 109, coherent
# values: 571, cold
# values: 132, cole
# values: 343, collection
# values: 496, college
# values: 106, colonel
# values: 402, color
# values: 144, colorful
# values: 199, colors
# values: 138, colour
# values: 206, columbo
# values: 218, com
# values: 109, combat
# values: 231, combination
# values: 94, combine
# values: 198, combined
# values: 3189, come
# values: 159, comedian
# values: 315, comedic
# values: 439, comedies
# values: 3244, comedy
# values: 2484, comes
# values: 80, comfort
# values: 110, comfortable
# values: 901, comic
# values: 171, comical
# values: 133, comics
# values: 1062, coming
# values: 99, command
# values: 653, comment
# values: 318, commentary
# values: 100, commented
# values: 779, comments
# values: 239, commercial
# values: 116, commercials
# values: 127, commit
# values: 195, committed
# values: 509, common
# values: 103, communist
# values: 290, community
# values: 80, companies
# values: 104, companion
# values: 515, company
# values: 325, compare
# values: 538, compared
# values: 96, comparing
# values: 251, comparison
# values: 81, compassion
# values: 87, compelled
# values: 385, compelling
# values: 140, competent
# values: 127, competition
# values: 115, complain
# values: 139, complaint
# values: 1035, complete
# values: 1889, completely
# values: 427, complex
# values: 90, complexity
# values: 178, complicated
# values: 111, composed
# values: 82, composer
# values: 468, computer
# values: 180, con
# values: 120, conceived
# values: 520, concept
# values: 97, concern
# values: 269, concerned
# values: 115, concerning
# values: 140, concerns
# values: 143, concert
# values: 490, conclusion
# values: 143, condition
# values: 80, conditions
# values: 81, confess
# values: 95, confidence
# values: 273, conflict
# values: 93, conflicts
# values: 79, confrontation
# values: 377, confused
# values: 368, confusing
# values: 163, confusion
# values: 117, connect
# values: 147, connected
# values: 258, connection
# values: 94, connery
# values: 79, conscious
# values: 123, consequences
# values: 95, conservative
# values: 513, consider
# values: 97, considerable
# values: 483, considered
# values: 545, considering
# values: 96, consistent
# values: 104, consistently
# values: 144, consists
# values: 126, conspiracy
# values: 291, constant
# values: 416, constantly
# values: 95, constructed
# values: 91, construction
# values: 151, contact
# values: 156, contain
# values: 113, contained
# values: 411, contains
# values: 211, contemporary
# values: 366, content
# values: 83, contest
# values: 260, context
# values: 307, continue
# values: 128, continued
# values: 261, continues
# values: 212, continuity
# values: 130, contract
# values: 116, contrary
# values: 224, contrast
# values: 227, contrived
# values: 510, control
# values: 152, controversial
# values: 109, conventional
# values: 188, conversation
# values: 110, conversations
# values: 171, convey
# values: 197, convince
# values: 216, convinced
# values: 538, convincing
# values: 93, convincingly
# values: 121, convoluted
# values: 159, cook
# values: 971, cool
# values: 166, cooper
# values: 620, cop
# values: 90, copies
# values: 301, cops
# values: 575, copy
# values: 259, core
# values: 153, corner
# values: 258, corny
# values: 96, corporate
# values: 127, corpse
# values: 223, correct
# values: 82, correctly
# values: 133, corrupt
# values: 100, corruption
# values: 220, cost
# values: 233, costs
# values: 223, costume
# values: 418, costumes
# values: 7922, could
# values: 352, count
# values: 87, counter
# values: 136, countless
# values: 151, countries
# values: 935, country
# values: 103, countryside
# values: 1719, couple
# values: 93, couples
# values: 148, courage
# values: 2506, course
# values: 193, court
# values: 147, cousin
# values: 526, cover
# values: 212, covered
# values: 135, covers
# values: 212, cowboy
# values: 132, cox
# values: 106, crack
# values: 79, cracking
# values: 113, craft
# values: 167, crafted
# values: 122, craig
# values: 1039, crap
# values: 242, crappy
# values: 201, crash
# values: 118, craven
# values: 82, crawford
# values: 79, crazed
# values: 657, crazy
# values: 78, cream
# values: 612, create
# values: 542, created
# values: 245, creates
# values: 284, creating
# values: 129, creation
# values: 362, creative
# values: 85, creativity
# values: 92, creator
# values: 127, creators
# values: 340, creature
# values: 214, creatures
# values: 153, credibility
# values: 153, credible
# values: 530, credit
# values: 674, credits
# values: 91, creep
# values: 638, creepy
# values: 570, crew
# values: 117, cried
# values: 757, crime
# values: 139, crimes
# values: 325, criminal
# values: 174, criminals
# values: 107, cringe
# values: 152, crisis
# values: 124, critic
# values: 175, critical
# values: 173, criticism
# values: 398, critics
# values: 94, crocodile
# values: 325, cross
# values: 226, crowd
# values: 86, crucial
# values: 187, crude
# values: 181, cruel
# values: 128, cruise
# values: 102, crush
# values: 399, cry
# values: 191, crying
# values: 83, crystal
# values: 109, cuba
# values: 147, cube
# values: 483, cult
# values: 184, cultural
# values: 495, culture
# values: 124, cup
# values: 101, cure
# values: 124, curiosity
# values: 262, curious
# values: 257, current
# values: 113, currently
# values: 147, curse
# values: 142, curtis
# values: 137, cusack
# values: 1035, cut
# values: 581, cute
# values: 274, cuts
# values: 211, cutting
# values: 154, cynical
# values: 80, da
# values: 491, dad
# values: 107, daddy
# values: 163, daily
# values: 97, dalton
# values: 108, damage
# values: 84, damme
# values: 356, damn
# values: 89, damon
# values: 264, dan
# values: 83, dana
# values: 744, dance
# values: 149, dancer
# values: 116, dancers
# values: 103, dances
# values: 529, dancing
# values: 116, danes
# values: 215, danger
# values: 291, dangerous
# values: 237, daniel
# values: 330, danny
# values: 138, dare
# values: 114, daring
# values: 1380, dark
# values: 117, darker
# values: 193, darkness
# values: 83, darren
# values: 436, date
# values: 267, dated
# values: 107, dating
# values: 1138, daughter
# values: 174, daughters
# values: 117, dave
# values: 1024, david
# values: 129, davies
# values: 354, davis
# values: 136, dawn
# values: 130, dawson
# values: 2746, day
# values: 1268, days
# values: 730, de
# values: 1881, dead
# values: 201, deadly
# values: 82, deaf
# values: 717, deal
# values: 267, dealing
# values: 258, deals
# values: 137, dealt
# values: 188, dean
# values: 146, dear
# values: 1908, death
# values: 205, deaths
# values: 260, debut
# values: 255, decade
# values: 177, decades
# values: 82, deceased
# values: 1157, decent
# values: 482, decide
# values: 705, decided
# values: 546, decides
# values: 240, decision
# values: 105, decisions
# values: 99, dedicated
# values: 82, dee
# values: 653, deep
# values: 177, deeper
# values: 320, deeply
# values: 107, defeat
# values: 95, defend
# values: 86, defense
# values: 87, defined
# values: 117, definite
# values: 1580, definitely
# values: 83, definition
# values: 204, degree
# values: 97, del
# values: 108, deliberately
# values: 157, delight
# values: 274, delightful
# values: 328, deliver
# values: 243, delivered
# values: 94, delivering
# values: 356, delivers
# values: 184, delivery
# values: 90, demand
# values: 113, demands
# values: 89, demented
# values: 79, demise
# values: 183, demon
# values: 192, demons
# values: 82, deniro
# values: 176, dennis
# values: 152, dentist
# values: 141, denzel
# values: 194, department
# values: 210, depicted
# values: 82, depicting
# values: 172, depiction
# values: 90, depicts
# values: 99, depressed
# values: 226, depressing
# values: 129, depression
# values: 511, depth
# values: 86, der
# values: 151, derek
# values: 89, descent
# values: 330, describe
# values: 233, described
# values: 102, describes
# values: 175, description
# values: 250, desert
# values: 287, deserve
# values: 291, deserved
# values: 591, deserves
# values: 342, design
# values: 206, designed
# values: 91, designs
# values: 304, desire
# values: 91, desired
# values: 86, despair
# values: 323, desperate
# values: 179, desperately
# values: 104, desperation
# values: 1364, despite
# values: 104, destiny
# values: 219, destroy
# values: 178, destroyed
# values: 94, destroying
# values: 142, destruction
# values: 345, detail
# values: 108, detailed
# values: 410, details
# values: 460, detective
# values: 164, determined
# values: 252, develop
# values: 404, developed
# values: 102, developing
# values: 641, development
# values: 144, develops
# values: 181, device
# values: 314, devil
# values: 104, devoid
# values: 109, devoted
# values: 769, dialog
# values: 142, dialogs
# values: 1542, dialogue
# values: 110, dialogues
# values: 125, diamond
# values: 101, diana
# values: 103, diane
# values: 295, dick
# values: 94, dickens
# values: 794, die
# values: 512, died
# values: 386, dies
# values: 376, difference
# values: 115, differences
# values: 2385, different
# values: 695, difficult
# values: 142, dig
# values: 126, digital
# values: 118, dignity
# values: 83, dimension
# values: 255, dimensional
# values: 82, din
# values: 154, dinner
# values: 99, dinosaur
# values: 111, dinosaurs
# values: 122, dire
# values: 366, direct
# values: 1204, directed
# values: 644, directing
# values: 1373, direction
# values: 80, directions
# values: 193, directly
# values: 4444, director
# values: 121, directorial
# values: 675, directors
# values: 103, directs
# values: 334, dirty
# values: 131, disagree
# values: 101, disappear
# values: 99, disappeared
# values: 98, disappoint
# values: 917, disappointed
# values: 420, disappointing
# values: 404, disappointment
# values: 320, disaster
# values: 175, disbelief
# values: 119, disc
# values: 266, discover
# values: 267, discovered
# values: 240, discovers
# values: 116, discovery
# values: 106, discuss
# values: 118, discussion
# values: 128, disease
# values: 221, disgusting
# values: 102, disjointed
# values: 150, dislike
# values: 79, disliked
# values: 754, disney
# values: 205, display
# values: 99, displayed
# values: 114, displays
# values: 118, distance
# values: 124, distant
# values: 84, distinct
# values: 107, distracting
# values: 82, distribution
# values: 107, disturbed
# values: 484, disturbing
# values: 102, divorce
# values: 94, dixon
# values: 137, doc
# values: 625, doctor
# values: 121, documentaries
# values: 953, documentary
# values: 688, dog
# values: 199, dogs
# values: 104, doll
# values: 169, dollar
# values: 200, dollars
# values: 96, dolls
# values: 85, dolph
# values: 86, domestic
# values: 98, domino
# values: 191, donald
# values: 3096, done
# values: 115, donna
# values: 123, doo
# values: 90, doom
# values: 104, doomed
# values: 432, door
# values: 125, doors
# values: 142, dorothy
# values: 399, double
# values: 757, doubt
# values: 82, doubts
# values: 315, douglas
# values: 79, downey
# values: 96, downhill
# values: 188, downright
# values: 196, dozen
# values: 103, dozens
# values: 702, dr
# values: 121, dracula
# values: 211, drag
# values: 138, dragged
# values: 186, dragon
# values: 130, drags
# values: 89, drake
# values: 1411, drama
# values: 141, dramas
# values: 667, dramatic
# values: 198, draw
# values: 114, drawing
# values: 428, drawn
# values: 118, draws
# values: 240, dreadful
# values: 663, dream
# values: 436, dreams
# values: 87, dreary
# values: 81, dreck
# values: 181, dress
# values: 293, dressed
# values: 86, dressing
# values: 245, drew
# values: 148, drink
# values: 175, drinking
# values: 448, drive
# values: 125, drivel
# values: 239, driven
# values: 195, driver
# values: 155, drives
# values: 269, driving
# values: 205, drop
# values: 131, dropped
# values: 85, dropping
# values: 102, drops
# values: 403, drug
# values: 325, drugs
# values: 292, drunk
# values: 119, drunken
# values: 230, dry
# values: 96, dub
# values: 224, dubbed
# values: 153, dubbing
# values: 83, dud
# values: 183, dude
# values: 909, due
# values: 132, duke
# values: 816, dull
# values: 609, dumb
# values: 121, duo
# values: 91, dust
# values: 104, dutch
# values: 106, duty
# values: 2345, dvd
# values: 314, dying
# values: 112, dynamic
# values: 94, eager
# values: 86, ear
# values: 87, earl
# values: 662, earlier
# values: 1605, early
# values: 100, earned
# values: 99, ears
# values: 928, earth
# values: 110, ease
# values: 132, easier
# values: 892, easily
# values: 170, east
# values: 83, eastern
# values: 138, eastwood
# values: 802, easy
# values: 275, eat
# values: 90, eaten
# values: 278, eating
# values: 109, eccentric
# values: 341, ed
# values: 310, eddie
# values: 95, edgar
# values: 441, edge
# values: 82, edgy
# values: 107, edie
# values: 262, edited
# values: 774, editing
# values: 89, edition
# values: 119, editor
# values: 97, education
# values: 83, educational
# values: 204, edward
# values: 141, eerie
# values: 633, effect
# values: 512, effective
# values: 187, effectively
# values: 2204, effects
# values: 792, effort
# values: 254, efforts
# values: 128, ego
# values: 221, eight
# values: 101, eighties
# values: 1866, either
# values: 118, elaborate
# values: 119, elderly
# values: 93, elegant
# values: 392, element
# values: 783, elements
# values: 99, elephant
# values: 175, elizabeth
# values: 122, ellen
# values: 84, elm
# values: 1998, else
# values: 139, elsewhere
# values: 153, elvira
# values: 154, elvis
# values: 158, em
# values: 163, embarrassed
# values: 226, embarrassing
# values: 96, embarrassment
# values: 122, emily
# values: 202, emma
# values: 396, emotion
# values: 657, emotional
# values: 241, emotionally
# values: 389, emotions
# values: 84, empathy
# values: 97, emperor
# values: 101, emphasis
# values: 124, empire
# values: 274, empty
# values: 90, en
# values: 175, encounter
# values: 140, encounters
# values: 5648, end
# values: 139, endearing
# values: 556, ended
# values: 2358, ending
# values: 104, endings
# values: 235, endless
# values: 984, ends
# values: 99, endure
# values: 104, enemies
# values: 203, enemy
# values: 317, energy
# values: 93, engage
# values: 110, engaged
# values: 312, engaging
# values: 305, england
# values: 986, english
# values: 1812, enjoy
# values: 842, enjoyable
# values: 1245, enjoyed
# values: 162, enjoying
# values: 150, enjoyment
# values: 112, enjoys
# values: 103, enormous
# values: 3452, enough
# values: 149, ensemble
# values: 88, ensues
# values: 196, enter
# values: 104, enterprise
# values: 131, enters
# values: 172, entertain
# values: 237, entertained
# values: 1442, entertaining
# values: 878, entertainment
# values: 86, enthusiasm
# values: 1460, entire
# values: 532, entirely
# values: 145, entry
# values: 175, environment
# values: 318, epic
# values: 1659, episode
# values: 938, episodes
# values: 143, equal
# values: 432, equally
# values: 84, equipment
# values: 87, equivalent
# values: 79, er
# values: 614, era
# values: 265, eric
# values: 201, erotic
# values: 108, errors
# values: 538, escape
# values: 110, escaped
# values: 163, escapes
# values: 2535, especially
# values: 138, essence
# values: 162, essential
# values: 257, essentially
# values: 164, established
# values: 128, estate
# values: 103, et
# values: 1212, etc
# values: 92, ethan
# values: 83, eugene
# values: 216, europe
# values: 284, european
# values: 140, eva
# values: 117, eve
# values: 12646, even
# values: 246, evening
# values: 373, event
# values: 910, events
# values: 720, eventually
# values: 5995, ever
# values: 3978, every
# values: 411, everybody
# values: 167, everyday
# values: 2222, everyone
# values: 2321, everything
# values: 190, everywhere
# values: 223, evidence
# values: 127, evident
# values: 1448, evil
# values: 468, ex
# values: 189, exact
# values: 995, exactly
# values: 120, exaggerated
# values: 79, examination
# values: 1373, example
# values: 181, examples
# values: 2070, excellent
# values: 1129, except
# values: 401, exception
# values: 148, exceptional
# values: 86, exceptionally
# values: 87, excessive
# values: 80, exchange
# values: 230, excited
# values: 221, excitement
# values: 515, exciting
# values: 419, excuse
# values: 241, executed
# values: 189, execution
# values: 132, executive
# values: 130, exercise
# values: 300, exist
# values: 114, existed
# values: 259, existence
# values: 161, existent
# values: 161, exists
# values: 104, exotic
# values: 1176, expect
# values: 404, expectations
# values: 704, expected
# values: 588, expecting
# values: 81, expedition
# values: 140, expensive
# values: 1059, experience
# values: 192, experienced
# values: 200, experiences
# values: 170, experiment
# values: 79, experimental
# values: 90, experiments
# values: 176, expert
# values: 451, explain
# values: 285, explained
# values: 107, explaining
# values: 193, explains
# values: 290, explanation
# values: 119, explicit
# values: 233, exploitation
# values: 92, exploration
# values: 118, explore
# values: 106, explored
# values: 112, explosion
# values: 109, explosions
# values: 117, exposed
# values: 82, exposure
# values: 189, express
# values: 83, expressed
# values: 169, expression
# values: 155, expressions
# values: 115, extended
# values: 171, extent
# values: 315, extra
# values: 173, extraordinary
# values: 228, extras
# values: 350, extreme
# values: 1069, extremely
# values: 849, eye
# values: 133, eyed
# values: 1216, eyes
# values: 115, eyre
# values: 178, fabulous
# values: 1645, face
# values: 204, faced
# values: 345, faces
# values: 177, facial
# values: 96, facing
# values: 3523, fact
# values: 218, factor
# values: 142, factory
# values: 224, facts
# values: 285, fail
# values: 483, failed
# values: 119, failing
# values: 606, fails
# values: 247, failure
# values: 455, fair
# values: 587, fairly
# values: 214, fairy
# values: 297, faith
# values: 178, faithful
# values: 473, fake
# values: 122, falk
# values: 770, fall
# values: 165, fallen
# values: 383, falling
# values: 851, falls
# values: 193, false
# values: 230, fame
# values: 538, familiar
# values: 239, families
# values: 3200, family
# values: 771, famous
# values: 1911, fan
# values: 119, fancy
# values: 1421, fans
# values: 798, fantastic
# values: 649, fantasy
# values: 2978, far
# values: 122, farce
# values: 210, fare
# values: 115, farm
# values: 89, farrell
# values: 88, fascinated
# values: 391, fascinating
# values: 341, fashion
# values: 138, fashioned
# values: 897, fast
# values: 100, faster
# values: 275, fat
# values: 124, fatal
# values: 271, fate
# values: 2123, father
# values: 240, fault
# values: 97, faults
# values: 250, favor
# values: 1232, favorite
# values: 187, favorites
# values: 329, favourite
# values: 121, fay
# values: 153, fbi
# values: 538, fear
# values: 126, fears
# values: 791, feature
# values: 192, featured
# values: 643, features
# values: 277, featuring
# values: 82, fed
# values: 87, feed
# values: 2950, feel
# values: 1145, feeling
# values: 395, feelings
# values: 810, feels
# values: 236, feet
# values: 121, felix
# values: 346, fell
# values: 372, fellow
# values: 1528, felt
# values: 944, female
# values: 84, feminist
# values: 80, femme
# values: 137, fest
# values: 399, festival
# values: 103, fetched
# values: 116, fever
# values: 661, fi
# values: 133, fianc
# values: 476, fiction
# values: 188, fictional
# values: 84, fido
# values: 290, field
# values: 79, fields
# values: 127, fifteen
# values: 1148, fight
# values: 111, fighter
# values: 607, fighting
# values: 285, fights
# values: 758, figure
# values: 187, figured
# values: 191, figures
# values: 80, files
# values: 231, fill
# values: 551, filled
# values: 40147, film
# values: 763, filmed
# values: 393, filming
# values: 334, filmmaker
# values: 566, filmmakers
# values: 6887, films
# values: 1329, final
# values: 267, finale
# values: 1536, finally
# values: 105, financial
# values: 4131, find
# values: 358, finding
# values: 948, finds
# values: 1324, fine
# values: 278, finest
# values: 97, finger
# values: 410, finish
# values: 302, finished
# values: 632, fire
# values: 133, fired
# values: 81, firm
# values: 9061, first
# values: 90, firstly
# values: 157, fish
# values: 129, fisher
# values: 78, fishing
# values: 489, fit
# values: 215, fits
# values: 137, fitting
# values: 933, five
# values: 100, fix
# values: 78, flair
# values: 149, flash
# values: 176, flashback
# values: 240, flashbacks
# values: 577, flat
# values: 140, flaw
# values: 156, flawed
# values: 125, flawless
# values: 362, flaws
# values: 247, flesh
# values: 1258, flick
# values: 357, flicks
# values: 105, flies
# values: 177, flight
# values: 89, floating
# values: 281, floor
# values: 108, flop
# values: 107, florida
# values: 161, flow
# values: 232, fly
# values: 357, flying
# values: 147, flynn
# values: 509, focus
# values: 203, focused
# values: 182, focuses
# values: 106, focusing
# values: 116, folk
# values: 346, folks
# values: 785, follow
# values: 373, followed
# values: 564, following
# values: 499, follows
# values: 102, fond
# values: 111, fonda
# values: 333, food
# values: 219, fool
# values: 95, fooled
# values: 259, foot
# values: 651, footage
# values: 221, football
# values: 120, forbidden
# values: 514, force
# values: 660, forced
# values: 272, forces
# values: 304, ford
# values: 237, foreign
# values: 191, forest
# values: 392, forever
# values: 716, forget
# values: 205, forgettable
# values: 131, forgive
# values: 178, forgot
# values: 353, forgotten
# values: 765, form
# values: 179, format
# values: 509, former
# values: 100, forms
# values: 252, formula
# values: 98, formulaic
# values: 190, forth
# values: 159, fortunately
# values: 144, fortune
# values: 103, forty
# values: 651, forward
# values: 185, foster
# values: 81, fought
# values: 111, foul
# values: 2572, found
# values: 912, four
# values: 176, fourth
# values: 336, fox
# values: 246, frame
# values: 234, france
# values: 154, franchise
# values: 91, francis
# values: 123, francisco
# values: 98, franco
# values: 457, frank
# values: 92, frankenstein
# values: 90, frankie
# values: 256, frankly
# values: 117, freak
# values: 303, fred
# values: 287, freddy
# values: 697, free
# values: 242, freedom
# values: 188, freeman
# values: 789, french
# values: 87, frequent
# values: 157, frequently
# values: 376, fresh
# values: 198, friday
# values: 1442, friend
# values: 193, friendly
# values: 1788, friends
# values: 283, friendship
# values: 195, frightening
# values: 595, front
# values: 125, frustrated
# values: 79, frustrating
# values: 103, frustration
# values: 284, fu
# values: 114, fulci
# values: 1779, full
# values: 83, fuller
# values: 426, fully
# values: 2694, fun
# values: 106, funeral
# values: 173, funnier
# values: 358, funniest
# values: 4288, funny
# values: 83, furious
# values: 106, furthermore
# values: 83, fury
# values: 900, future
# values: 120, futuristic
# values: 121, fx
# values: 90, gabriel
# values: 110, gadget
# values: 140, gag
# values: 262, gags
# values: 143, gain
# values: 1281, game
# values: 340, games
# values: 121, gandhi
# values: 421, gang
# values: 259, gangster
# values: 94, gangsters
# values: 459, garbage
# values: 103, garbo
# values: 109, garden
# values: 272, gary
# values: 195, gas
# values: 1216, gave
# values: 609, gay
# values: 361, gem
# values: 90, gender
# values: 277, gene
# values: 765, general
# values: 468, generally
# values: 85, generated
# values: 235, generation
# values: 80, generations
# values: 105, generic
# values: 124, generous
# values: 452, genius
# values: 1254, genre
# values: 113, genres
# values: 116, gentle
# values: 84, gentleman
# values: 256, genuine
# values: 251, genuinely
# values: 862, george
# values: 91, gerard
# values: 516, german
# values: 91, germans
# values: 227, germany
# values: 9310, get
# values: 3204, gets
# values: 1627, getting
# values: 484, ghost
# values: 181, ghosts
# values: 118, giallo
# values: 379, giant
# values: 131, gift
# values: 84, gifted
# values: 107, ginger
# values: 2853, girl
# values: 636, girlfriend
# values: 1211, girls
# values: 3376, give
# values: 1846, given
# values: 1576, gives
# values: 839, giving
# values: 450, glad
# values: 157, glass
# values: 80, glasses
# values: 118, glenn
# values: 149, glimpse
# values: 94, global
# values: 104, glorious
# values: 147, glory
# values: 142, glover
# values: 5157, go
# values: 137, goal
# values: 1207, god
# values: 134, godfather
# values: 105, godzilla
# values: 2441, goes
# values: 4101, going
# values: 295, gold
# values: 123, goldberg
# values: 259, golden
# values: 754, gone
# values: 241, gonna
# values: 15140, good
# values: 106, goodness
# values: 161, goofy
# values: 245, gordon
# values: 1038, gore
# values: 368, gorgeous
# values: 234, gory
# values: 3583, got
# values: 136, gothic
# values: 129, gotta
# values: 286, gotten
# values: 424, government
# values: 109, grab
# values: 80, grabs
# values: 328, grace
# values: 462, grade
# values: 118, gradually
# values: 86, graham
# values: 307, grand
# values: 98, grandfather
# values: 127, grandmother
# values: 262, grant
# values: 201, granted
# values: 239, graphic
# values: 169, graphics
# values: 97, grasp
# values: 237, gratuitous
# values: 189, grave
# values: 121, gray
# values: 89, grayson
# values: 9058, great
# values: 174, greater
# values: 745, greatest
# values: 154, greatly
# values: 82, greatness
# values: 86, greed
# values: 91, greedy
# values: 113, greek
# values: 404, green
# values: 83, greg
# values: 79, gregory
# values: 250, grew
# values: 158, grey
# values: 79, grief
# values: 102, griffith
# values: 188, grim
# values: 103, grinch
# values: 150, gripping
# values: 196, gritty
# values: 180, gross
# values: 353, ground
# values: 1034, group
# values: 108, groups
# values: 224, grow
# values: 297, growing
# values: 252, grown
# values: 134, grows
# values: 163, gruesome
# values: 91, guarantee
# values: 165, guard
# values: 1310, guess
# values: 99, guessed
# values: 151, guessing
# values: 133, guest
# values: 125, guide
# values: 142, guilt
# values: 198, guilty
# values: 563, gun
# values: 94, gundam
# values: 283, guns
# values: 143, guts
# values: 3035, guy
# values: 1304, guys
# values: 184, ha
# values: 505, hair
# values: 105, hal
# values: 2094, half
# values: 173, halfway
# values: 221, hall
# values: 244, halloween
# values: 84, ham
# values: 113, hamilton
# values: 145, hamlet
# values: 111, hammer
# values: 1257, hand
# values: 181, handed
# values: 127, handful
# values: 167, handle
# values: 209, handled
# values: 632, hands
# values: 228, handsome
# values: 143, hang
# values: 215, hanging
# values: 105, hank
# values: 140, hanks
# values: 1043, happen
# values: 1076, happened
# values: 383, happening
# values: 1080, happens
# values: 152, happily
# values: 186, happiness
# values: 965, happy
# values: 2668, hard
# values: 102, hardcore
# values: 112, harder
# values: 613, hardly
# values: 177, hardy
# values: 81, harm
# values: 256, harris
# values: 461, harry
# values: 200, harsh
# values: 106, hart
# values: 101, hartley
# values: 107, harvey
# values: 212, hat
# values: 789, hate
# values: 296, hated
# values: 104, hates
# values: 121, hatred
# values: 217, haunted
# values: 229, haunting
# values: 79, hawke
# values: 108, hbo
# values: 1541, head
# values: 169, headed
# values: 291, heads
# values: 137, health
# values: 733, hear
# values: 1111, heard
# values: 231, hearing
# values: 1328, heart
# values: 225, hearted
# values: 135, hearts
# values: 128, heat
# values: 320, heaven
# values: 180, heavily
# values: 492, heavy
# values: 222, heck
# values: 85, heights
# values: 391, held
# values: 152, helen
# values: 97, helicopter
# values: 1025, hell
# values: 90, hello
# values: 1895, help
# values: 324, helped
# values: 176, helping
# values: 360, helps
# values: 155, hence
# values: 407, henry
# values: 1056, hero
# values: 318, heroes
# values: 115, heroic
# values: 291, heroine
# values: 136, heston
# values: 409, hey
# values: 342, hidden
# values: 210, hide
# values: 103, hideous
# values: 144, hiding
# values: 2161, high
# values: 289, higher
# values: 106, highest
# values: 202, highlight
# values: 125, highlights
# values: 1147, highly
# values: 973, hilarious
# values: 86, hilariously
# values: 243, hill
# values: 152, hills
# values: 147, hint
# values: 103, hints
# values: 181, hip
# values: 84, hippie
# values: 130, hire
# values: 188, hired
# values: 407, historical
# values: 86, historically
# values: 1332, history
# values: 1088, hit
# values: 209, hitchcock
# values: 305, hitler
# values: 272, hits
# values: 137, hitting
# values: 126, ho
# values: 188, hoffman
# values: 545, hold
# values: 209, holding
# values: 300, holds
# values: 167, hole
# values: 367, holes
# values: 148, holiday
# values: 113, hollow
# values: 107, holly
# values: 1907, hollywood
# values: 163, holmes
# values: 113, holy
# values: 133, homage
# values: 1877, home
# values: 140, homeless
# values: 103, homer
# values: 90, homosexual
# values: 481, honest
# values: 453, honestly
# values: 99, honesty
# values: 191, hong
# values: 173, honor
# values: 162, hood
# values: 99, hook
# values: 139, hooked
# values: 95, hop
# values: 1447, hope
# values: 144, hoped
# values: 214, hopefully
# values: 82, hopeless
# values: 273, hopes
# values: 407, hoping
# values: 98, hopper
# values: 134, horrendous
# values: 1201, horrible
# values: 214, horribly
# values: 116, horrid
# values: 159, horrific
# values: 95, horrifying
# values: 3592, horror
# values: 124, horrors
# values: 298, horse
# values: 145, horses
# values: 356, hospital
# values: 146, host
# values: 688, hot
# values: 397, hotel
# values: 1188, hour
# values: 983, hours
# values: 2184, house
# values: 84, household
# values: 105, houses
# values: 260, howard
# values: 3537, however
# values: 141, hudson
# values: 944, huge
# values: 111, hugh
# values: 138, huh
# values: 1596, human
# values: 282, humanity
# values: 319, humans
# values: 94, humble
# values: 1311, humor
# values: 263, humorous
# values: 441, humour
# values: 149, hundred
# values: 151, hundreds
# values: 98, hung
# values: 222, hunt
# values: 239, hunter
# values: 90, hunters
# values: 143, hunting
# values: 382, hurt
# values: 99, hurts
# values: 1026, husband
# values: 79, husbands
# values: 96, hyde
# values: 134, hype
# values: 117, hysterical
# values: 132, ian
# values: 282, ice
# values: 85, icon
# values: 2043, idea
# values: 103, ideal
# values: 595, ideas
# values: 130, identify
# values: 256, identity
# values: 185, idiot
# values: 145, idiotic
# values: 118, idiots
# values: 96, ignorant
# values: 177, ignore
# values: 120, ignored
# values: 366, ii
# values: 135, iii
# values: 290, ill
# values: 90, illegal
# values: 89, illness
# values: 98, illogical
# values: 92, im
# values: 379, image
# values: 186, imagery
# values: 472, images
# values: 356, imagination
# values: 140, imaginative
# values: 737, imagine
# values: 116, imagined
# values: 702, imdb
# values: 85, imitation
# values: 80, immediate
# values: 462, immediately
# values: 102, immensely
# values: 374, impact
# values: 108, implausible
# values: 134, importance
# values: 931, important
# values: 127, importantly
# values: 496, impossible
# values: 104, impress
# values: 352, impressed
# values: 405, impression
# values: 500, impressive
# values: 97, improve
# values: 115, improved
# values: 85, improvement
# values: 79, inability
# values: 95, inane
# values: 90, inappropriate
# values: 115, incident
# values: 375, include
# values: 272, included
# values: 321, includes
# values: 1052, including
# values: 138, incoherent
# values: 87, incompetent
# values: 89, incomprehensible
# values: 131, increasingly
# values: 563, incredible
# values: 626, incredibly
# values: 722, indeed
# values: 314, independent
# values: 179, india
# values: 405, indian
# values: 122, indians
# values: 181, indie
# values: 237, individual
# values: 126, individuals
# values: 83, inducing
# values: 80, indulgent
# values: 345, industry
# values: 175, inept
# values: 131, inevitable
# values: 82, inevitably
# values: 148, infamous
# values: 94, inferior
# values: 211, influence
# values: 107, influenced
# values: 335, information
# values: 107, ingredients
# values: 209, initial
# values: 178, initially
# values: 210, inner
# values: 154, innocence
# values: 416, innocent
# values: 110, innovative
# values: 241, insane
# values: 600, inside
# values: 187, insight
# values: 162, inspector
# values: 169, inspiration
# values: 348, inspired
# values: 135, inspiring
# values: 121, installment
# values: 289, instance
# values: 104, instant
# values: 128, instantly
# values: 2190, instead
# values: 86, instinct
# values: 213, insult
# values: 128, insulting
# values: 82, integrity
# values: 176, intellectual
# values: 327, intelligence
# values: 534, intelligent
# values: 388, intended
# values: 344, intense
# values: 158, intensity
# values: 117, intent
# values: 132, intention
# values: 90, intentionally
# values: 161, intentions
# values: 99, interaction
# values: 1033, interest
# values: 650, interested
# values: 3128, interesting
# values: 82, interests
# values: 266, international
# values: 155, internet
# values: 162, interpretation
# values: 180, interview
# values: 158, interviews
# values: 88, intimate
# values: 109, intrigue
# values: 120, intrigued
# values: 301, intriguing
# values: 84, introduce
# values: 313, introduced
# values: 99, introduces
# values: 168, introduction
# values: 91, invasion
# values: 80, invented
# values: 97, inventive
# values: 112, investigate
# values: 128, investigation
# values: 200, invisible
# values: 99, involve
# values: 1076, involved
# values: 114, involvement
# values: 224, involves
# values: 465, involving
# values: 93, iran
# values: 85, iraq
# values: 115, ireland
# values: 195, irish
# values: 94, iron
# values: 162, ironic
# values: 123, ironically
# values: 148, irony
# values: 85, irrelevant
# values: 231, irritating
# values: 535, island
# values: 98, isolated
# values: 85, israel
# values: 287, issue
# values: 418, issues
# values: 527, italian
# values: 153, italy
# values: 925, jack
# values: 232, jackie
# values: 340, jackson
# values: 172, jail
# values: 160, jake
# values: 1068, james
# values: 128, jamie
# values: 657, jane
# ...
# values: 93, stilted
# values: 102, stinker
# values: 97, stinks
# values: 255, stock
# values: 115, stole
# values: 190, stolen
# values: 167, stomach
# values: 356, stone
# values: 133, stood
# values: 95, stooges
# values: 1084, stop
# values: 230, stopped
# values: 158, stops
# values: 519, store
# values: 1179, stories
# values: 152, storm
# values: 11983, story
# values: 804, storyline
# values: 173, storytelling
# values: 864, straight
# values: 926, strange
# values: 166, strangely
# values: 155, stranger
# values: 81, strangers
# values: 103, streep
# values: 699, street
# values: 269, streets
# values: 152, streisand
# values: 245, strength
# values: 98, stress
# values: 144, stretch
# values: 83, stretched
# values: 129, strictly
# values: 131, strike
# values: 135, strikes
# values: 137, striking
# values: 124, string
# values: 143, strip
# values: 1096, strong
# values: 133, stronger
# values: 222, strongly
# values: 128, struck
# values: 206, structure
# values: 327, struggle
# values: 155, struggles
# values: 198, struggling
# values: 80, stuart
# values: 350, stuck
# values: 391, student
# values: 361, students
# values: 517, studio
# values: 181, studios
# values: 250, study
# values: 1174, stuff
# values: 78, stumbled
# values: 82, stunned
# values: 405, stunning
# values: 136, stunt
# values: 139, stunts
# values: 1701, stupid
# values: 158, stupidity
# values: 1601, style
# values: 114, styles
# values: 158, stylish
# values: 371, sub
# values: 709, subject
# values: 79, subjected
# values: 107, subjects
# values: 121, subplot
# values: 87, subplots
# values: 121, subsequent
# values: 219, substance
# values: 190, subtitles
# values: 434, subtle
# values: 102, subtlety
# values: 150, succeed
# values: 106, succeeded
# values: 167, succeeds
# values: 585, success
# values: 524, successful
# values: 161, successfully
# values: 177, suck
# values: 251, sucked
# values: 280, sucks
# values: 248, sudden
# values: 538, suddenly
# values: 91, sue
# values: 181, suffer
# values: 150, suffered
# values: 250, suffering
# values: 201, suffers
# values: 84, suffice
# values: 377, suggest
# values: 81, suggested
# values: 145, suggests
# values: 316, suicide
# values: 311, suit
# values: 94, suitable
# values: 111, suited
# values: 121, suits
# values: 192, sullivan
# values: 159, sum
# values: 178, summary
# values: 374, summer
# values: 193, sun
# values: 190, sunday
# values: 117, sunshine
# values: 500, super
# values: 671, superb
# values: 126, superbly
# values: 112, superficial
# values: 119, superhero
# values: 311, superior
# values: 308, superman
# values: 201, supernatural
# values: 393, support
# values: 81, supported
# values: 899, supporting
# values: 397, suppose
# values: 1516, supposed
# values: 365, supposedly
# values: 2683, sure
# values: 417, surely
# values: 192, surface
# values: 102, surfing
# values: 715, surprise
# values: 801, surprised
# values: 203, surprises
# values: 302, surprising
# values: 466, surprisingly
# values: 208, surreal
# values: 134, surrounded
# values: 134, surrounding
# values: 106, survival
# values: 260, survive
# values: 91, survived
# values: 104, surviving
# values: 85, survivor
# values: 101, survivors
# values: 186, susan
# values: 301, suspect
# values: 156, suspects
# values: 84, suspend
# values: 739, suspense
# values: 192, suspenseful
# values: 88, suspicious
# values: 160, sutherland
# values: 113, swear
# values: 112, swedish
# values: 572, sweet
# values: 83, swim
# values: 97, swimming
# values: 97, switch
# values: 195, sword
# values: 114, symbolism
# values: 229, sympathetic
# values: 199, sympathy
# values: 111, synopsis
# values: 370, system
# values: 181, table
# values: 79, tacky
# values: 97, tad
# values: 99, tag
# values: 3507, take
# values: 986, taken
# values: 2192, takes
# values: 955, taking
# values: 790, tale
# values: 933, talent
# values: 586, talented
# values: 268, talents
# values: 166, tales
# values: 842, talk
# values: 126, talked
# values: 954, talking
# values: 220, talks
# values: 121, tall
# values: 111, tame
# values: 80, tank
# values: 115, tap
# values: 234, tape
# values: 82, tarantino
# values: 211, target
# values: 291, tarzan
# values: 174, task
# values: 437, taste
# values: 95, taught
# values: 91, taxi
# values: 315, taylor
# values: 136, tea
# values: 137, teach
# values: 314, teacher
# values: 82, teaching
# values: 823, team
# values: 138, tear
# values: 324, tears
# values: 82, tech
# values: 305, technical
# values: 195, technically
# values: 80, technicolor
# values: 150, technique
# values: 136, techniques
# values: 245, technology
# values: 198, ted
# values: 218, tedious
# values: 339, teen
# values: 325, teenage
# values: 221, teenager
# values: 217, teenagers
# values: 198, teens
# values: 181, teeth
# values: 904, television
# values: 1718, tell
# values: 613, telling
# values: 880, tells
# values: 122, temple
# values: 829, ten
# values: 215, tend
# values: 101, tender
# values: 86, tends
# values: 152, tense
# values: 541, tension
# values: 167, term
# values: 433, terms
# values: 1638, terrible
# values: 274, terribly
# values: 433, terrific
# values: 142, terrifying
# values: 123, territory
# values: 197, terror
# values: 103, terrorist
# values: 89, terrorists
# values: 112, terry
# values: 236, test
# values: 83, testament
# values: 210, texas
# values: 158, text
# values: 745, th
# values: 439, thank
# values: 182, thankfully
# values: 472, thanks
# values: 345, thats
# values: 828, theater
# values: 229, theaters
# values: 319, theatre
# values: 228, theatrical
# values: 816, theme
# values: 423, themes
# values: 192, theory
# values: 335, therefore
# values: 116, thick
# values: 158, thief
# values: 360, thin
# values: 4526, thing
# values: 3688, things
# values: 7296, think
# values: 1179, thinking
# values: 437, thinks
# values: 739, third
# values: 141, thirty
# values: 254, thomas
# values: 85, thompson
# values: 350, thoroughly
# values: 4566, though
# values: 3437, thought
# values: 98, thoughtful
# values: 219, thoughts
# values: 145, thousand
# values: 153, thousands
# values: 116, threat
# values: 126, threatening
# values: 2295, three
# values: 112, threw
# values: 111, thrill
# values: 895, thriller
# values: 151, thrillers
# values: 157, thrilling
# values: 129, thrills
# values: 122, throat
# values: 1360, throughout
# values: 402, throw
# values: 173, throwing
# values: 409, thrown
# values: 167, throws
# values: 97, thru
# values: 111, thugs
# values: 136, thumbs
# values: 418, thus
# values: 124, ticket
# values: 102, tie
# values: 149, tied
# values: 104, ties
# values: 87, tiger
# values: 182, tight
# values: 213, till
# values: 309, tim
# values: 12724, time
# values: 121, timeless
# values: 3235, times
# values: 169, timing
# values: 94, timon
# values: 118, timothy
# values: 214, tiny
# values: 380, tired
# values: 92, tiresome
# values: 190, titanic
# values: 1497, title
# values: 121, titled
# values: 172, titles
# values: 1243, today
# values: 112, todd
# values: 2243, together
# values: 130, toilet
# values: 1063, told
# values: 785, tom
# values: 88, tomatoes
# values: 113, tommy
# values: 500, tone
# values: 156, tongue
# values: 96, tonight
# values: 134, tons
# values: 522, tony
# values: 1100, took
# values: 86, tooth
# values: 1847, top
# values: 160, topic
# values: 101, topless
# values: 154, torn
# values: 300, torture
# values: 116, tortured
# values: 631, total
# values: 1307, totally
# values: 472, touch
# values: 170, touched
# values: 206, touches
# values: 435, touching
# values: 479, tough
# values: 154, tour
# values: 285, toward
# values: 637, towards
# values: 1279, town
# values: 169, toy
# values: 107, toys
# values: 399, track
# values: 105, tracks
# values: 165, tracy
# values: 140, trade
# values: 81, trademark
# values: 162, tradition
# values: 257, traditional
# values: 362, tragedy
# values: 348, tragic
# values: 83, trail
# values: 377, trailer
# values: 102, trailers
# values: 411, train
# values: 97, trained
# values: 218, training
# values: 95, transfer
# values: 100, transformation
# values: 91, transition
# values: 117, translation
# values: 124, trap
# values: 188, trapped
# values: 504, trash
# values: 99, trashy
# values: 246, travel
# values: 101, traveling
# values: 105, travels
# values: 84, travesty
# values: 202, treasure
# values: 320, treat
# values: 275, treated
# values: 235, treatment
# values: 97, treats
# values: 175, tree
# values: 104, trees
# values: 259, trek
# values: 127, tremendous
# values: 152, trial
# values: 84, tribe
# values: 138, tribute
# values: 171, trick
# values: 137, tricks
# values: 773, tried
# values: 1274, tries
# values: 216, trilogy
# values: 112, trio
# values: 492, trip
# values: 152, trite
# values: 115, triumph
# values: 89, troops
# values: 522, trouble
# values: 145, troubled
# values: 84, troubles
# values: 174, truck
# values: 2333, true
# values: 1743, truly
# values: 321, trust
# values: 700, truth
# values: 1830, try
# values: 2473, trying
# values: 79, tube
# values: 145, tune
# values: 119, tunes
# values: 173, turkey
# values: 1359, turn
# values: 925, turned
# values: 122, turner
# values: 344, turning
# values: 1251, turns
# values: 2782, tv
# values: 115, twelve
# values: 299, twenty
# values: 387, twice
# values: 89, twilight
# values: 126, twin
# values: 81, twins
# values: 606, twist
# values: 199, twisted
# values: 437, twists
# values: 6906, two
# values: 1124, type
# values: 247, types
# values: 778, typical
# values: 130, typically
# values: 354, ugly
# values: 229, uk
# values: 248, ultimate
# values: 521, ultimately
# values: 140, ultra
# values: 190, un
# values: 247, unable
# values: 83, unaware
# values: 116, unbearable
# values: 434, unbelievable
# values: 116, unbelievably
# values: 335, uncle
# values: 149, uncomfortable
# values: 186, unconvincing
# values: 174, underground
# values: 82, underlying
# values: 235, underrated
# values: 1643, understand
# values: 97, understandable
# values: 275, understanding
# values: 90, understated
# values: 179, understood
# values: 107, undoubtedly
# values: 107, uneven
# values: 250, unexpected
# values: 79, unexpectedly
# values: 80, unfair
# values: 104, unfolds
# values: 143, unforgettable
# values: 208, unfortunate
# values: 1352, unfortunately
# values: 267, unfunny
# values: 96, unhappy
# values: 123, uninspired
# values: 108, unintentional
# values: 135, unintentionally
# values: 198, uninteresting
# values: 128, union
# values: 634, unique
# values: 89, unit
# values: 216, united
# values: 217, universal
# values: 197, universe
# values: 131, university
# values: 286, unknown
# values: 675, unless
# values: 585, unlike
# values: 211, unlikely
# values: 307, unnecessary
# values: 83, unoriginal
# values: 110, unpleasant
# values: 82, unpredictable
# values: 84, unreal
# values: 226, unrealistic
# values: 83, unseen
# values: 99, unsettling
# values: 310, unusual
# values: 106, unwatchable
# values: 81, uplifting
# values: 859, upon
# values: 158, upper
# values: 266, ups
# values: 154, upset
# values: 189, urban
# values: 102, urge
# values: 3794, us
# values: 164, usa
# values: 1803, use
# values: 1879, used
# values: 94, useful
# values: 128, useless
# values: 102, user
# values: 540, uses
# values: 801, using
# values: 83, ustinov
# values: 965, usual
# values: 981, usually
# values: 240, utter
# values: 454, utterly
# values: 102, uwe
# values: 159, vacation
# values: 129, vague
# values: 90, vaguely
# values: 80, valentine
# values: 82, valley
# values: 93, valuable
# values: 524, value
# values: 467, values
# values: 419, vampire
# values: 249, vampires
# values: 495, van
# values: 79, vance
# values: 192, variety
# values: 603, various
# values: 100, vast
# values: 95, vegas
# values: 236, vehicle
# values: 94, vengeance
# values: 118, verhoeven
# values: 2157, version
# values: 253, versions
# values: 109, versus
# values: 201, veteran
# values: 282, vhs
# values: 169, via
# values: 92, vice
# values: 116, vicious
# values: 416, victim
# values: 377, victims
# values: 236, victor
# values: 233, victoria
# values: 80, victory
# values: 1730, video
# values: 136, videos
# values: 192, vietnam
# values: 963, view
# values: 210, viewed
# values: 1262, viewer
# values: 785, viewers
# values: 750, viewing
# values: 88, viewings
# values: 182, views
# values: 255, village
# values: 600, villain
# values: 278, villains
# values: 145, vincent
# values: 1091, violence
# values: 523, violent
# values: 149, virgin
# values: 94, virginia
# values: 214, virtually
# values: 139, virus
# values: 89, visible
# values: 304, vision
# values: 262, visit
# values: 89, visits
# values: 523, visual
# values: 259, visually
# values: 253, visuals
# values: 109, vivid
# values: 1156, voice
# values: 98, voiced
# values: 218, voices
# values: 111, voight
# values: 184, von
# values: 222, vote
# values: 273, vs
# values: 91, vulnerable
# values: 84, wacky
# values: 718, wait
# values: 95, waited
# values: 549, waiting
# values: 85, waitress
# values: 140, wake
# values: 511, walk
# values: 195, walked
# values: 142, walken
# values: 117, walker
# values: 439, walking
# values: 213, walks
# values: 367, wall
# values: 116, wallace
# values: 133, walls
# values: 86, walsh
# values: 221, walter
# values: 90, wandering
# values: 81, wang
# values: 158, wanna
# values: 117, wannabe
# values: 3703, want
# values: 1352, wanted
# values: 298, wanting
# values: 1287, wants
# values: 2051, war
# values: 126, ward
# values: 227, warm
# values: 109, warming
# values: 86, warmth
# values: 153, warn
# values: 174, warned
# values: 177, warner
# values: 314, warning
# values: 117, warren
# values: 120, warrior
# values: 82, warriors
# values: 332, wars
# values: 272, washington
# values: 1457, waste
# values: 560, wasted
# values: 150, wasting
# values: 6973, watch
# values: 307, watchable
# values: 2236, watched
# values: 122, watches
# values: 4603, watching
# values: 547, water
# values: 108, waters
# values: 85, watson
# values: 173, wave
# values: 93, waves
# values: 8026, way
# values: 236, wayne
# values: 804, ways
# values: 761, weak
# values: 99, weakest
# values: 109, wealth
# values: 153, wealthy
# values: 148, weapon
# values: 168, weapons
# values: 186, wear
# values: 326, wearing
# values: 166, wears
# values: 114, web
# values: 112, website
# values: 304, wedding
# values: 460, week
# values: 207, weekend
# values: 202, weeks
# values: 139, weight
# values: 663, weird
# values: 214, welcome
# values: 10662, well
# values: 251, welles
# values: 121, wells
# values: 98, wendy
# values: 1463, went
# values: 272, werewolf
# values: 121, wes
# values: 476, west
# values: 600, western
# values: 164, westerns
# values: 96, wet
# values: 116, whale
# values: 732, whatever
# values: 85, whats
# values: 319, whatsoever
# values: 270, whenever
# values: 149, whereas
# values: 856, whether
# values: 280, whilst
# values: 1492, white
# values: 202, whoever
# values: 3078, whole
# values: 82, wholly
# values: 84, whoopi
# values: 986, whose
# values: 118, wicked
# values: 281, wide
# values: 87, widely
# values: 155, widmark
# values: 105, widow
# values: 2140, wife
# values: 432, wild
# values: 80, wilderness
# values: 596, william
# values: 344, williams
# values: 85, willie
# values: 320, willing
# values: 92, willis
# values: 200, wilson
# values: 491, win
# values: 274, wind
# values: 257, window
# values: 102, winds
# values: 177, wing
# values: 232, winner
# values: 348, winning
# values: 164, wins
# values: 137, winter
# values: 105, winters
# values: 89, wisdom
# values: 359, wise
# values: 957, wish
# values: 95, wished
# values: 154, wishes
# values: 85, wishing
# values: 234, wit
# values: 322, witch
# values: 92, witches
# values: 832, within
# values: 3267, without
# values: 210, witness
# values: 88, witnessed
# values: 89, witnesses
# values: 273, witty
# values: 105, wives
# values: 95, wizard
# values: 120, wolf
# values: 2795, woman
# values: 1819, women
# values: 1038, wonder
# values: 126, wondered
# values: 1656, wonderful
# values: 324, wonderfully
# values: 358, wondering
# values: 125, wonders
# values: 101, wont
# values: 80, woo
# values: 271, wood
# values: 330, wooden
# values: 400, woods
# values: 240, woody
# values: 926, word
# values: 885, words
# values: 98, wore
# values: 4372, work
# values: 635, worked
# values: 129, worker
# values: 165, workers
# values: 794, working
# values: 1278, works
# values: 3835, world
# values: 143, worlds
# values: 88, worn
# values: 117, worried
# values: 142, worry
# values: 1468, worse
# values: 2731, worst
# values: 2277, worth
# values: 126, worthless
# values: 187, worthwhile
# values: 362, worthy
# values: 12436, would
# values: 94, wound
# values: 84, wounded
# values: 431, wow
# values: 87, wrap
# values: 92, wrapped
# values: 127, wreck
# values: 103, wrestling
# values: 79, wretched
# values: 670, write
# values: 1153, writer
# values: 661, writers
# values: 94, writes
# values: 1304, writing
# values: 1616, written
# values: 1821, wrong
# values: 573, wrote
# values: 85, ww
# values: 158, wwii
# values: 103, ya
# values: 82, yard
# values: 462, yeah
# values: 2362, year
# values: 4516, years
# values: 92, yelling
# values: 106, yellow
# values: 1535, yes
# values: 116, yesterday
# values: 2753, yet
# values: 809, york
# values: 3660, young
# values: 503, younger
# values: 275, youth
# values: 384, zero
# values: 85, zizek
# values: 740, zombie
# values: 518, zombies
# values: 147, zone

# %% [markdown]
# # Random Forest approach

# %%
print("Training the random forest...")
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable
#
# This may take a few minutes to run
X=train_data_features
y=train["sentiment"]
forest = forest.fit( train_data_features, train["sentiment"] )
# Out:
# Training the random forest...

# %%
from sklearn.datasets import make_classification

clf = RandomForestClassifier(n_estimators = 100)
clf.fit(X, y)

print(clf.predict([[0, 0, 0, 0]]))

# %%
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
#split the dataset into training (70%) and testing (30%) sets
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %%
#define metrics
y_pred_proba = forest.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# # Creating a Submission

# %%
# Read the test data
test = pd.read_csv("testData.tsv", header=0, delimiter="\t", \
                   quoting=3 )

# Verify that there are 25,000 rows and 2 columns
print(test.shape)
# Out:
# (25000, 2)

# %%
# Create an empty list and append the clean reviews one by one
num_reviews = len(test["review"])
clean_test_reviews = [] 

print("Cleaning and parsing the test set movie reviews...\n")

for i in xrange(0,num_reviews):
    if( (i+1) % 1000 == 0 ):
        print("Review %d of %d\n" % (i+1, num_reviews))
    clean_review = review_to_words( test["review"][i] )
    clean_test_reviews.append( clean_review )
# Out:
# Cleaning and parsing the test set movie reviews...
#
# Review 1000 of 25000
#
# Review 2000 of 25000
#
# Review 3000 of 25000
#
# Review 4000 of 25000
#
# Review 5000 of 25000
#
# Review 6000 of 25000
#
# Review 7000 of 25000
#
# Review 8000 of 25000
#
# Review 9000 of 25000
#
# Review 10000 of 25000
#
# Review 11000 of 25000
#
# Review 12000 of 25000
#
# Review 13000 of 25000
#
# Review 14000 of 25000
#
# Review 15000 of 25000
#
# Review 16000 of 25000
#
# Review 17000 of 25000
#
# Review 18000 of 25000
#
# Review 19000 of 25000
#
# Review 20000 of 25000
#
# Review 21000 of 25000
#
# Review 22000 of 25000
#
# Review 23000 of 25000
#
# Review 24000 of 25000
#
# Review 25000 of 25000

# %%
# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_reviews)
test_data_features = test_data_features.toarray()

# Use the random forest to make sentiment label predictions
result = forest.predict(test_data_features)

# Copy the results to a pandas dataframe with an "id" column and
# a "sentiment" column
output = pd.DataFrame( data={"id":test["id"], "sentiment":result} )

# Use pandas to write the comma-separated output file
output.to_csv( "Bag_of_Words_model.csv", index=False, quoting=3 )

# %%
#output['id'].values
#output.shape

# %% [markdown]
# # PART II

# %%
# Read data from files 
train = pd.read_csv( "labeledTrainData.tsv", header=0, 
 delimiter="\t", quoting=3 )
test = pd.read_csv( "testData.tsv", header=0, delimiter="\t", quoting=3 )
unlabeled_train = pd.read_csv( "unlabeledTrainData.tsv", header=0, 
 delimiter="\t", quoting=3 )

# Verify the number of reviews that were read (100,000 in total)
print("Read %d labeled train reviews, %d labeled test reviews, " \
 "and %d unlabeled reviews\n" % (train["review"].size,  
 test["review"].size, unlabeled_train["review"].size ))
# Out:
# Read 25000 labeled train reviews, 25000 labeled test reviews, and 50000 unlabeled reviews

# %%
# Import various modules for string cleaning
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords

def review_to_wordlist( review, remove_stopwords=False ):
    # Function to convert a document to a sequence of words,
    # optionally removing stop words.  Returns a list of words.
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(review).get_text()
    #  
    # 2. Remove non-letters
    review_text = re.sub("[^a-zA-Z]"," ", review_text)
    #
    # 3. Convert words to lower case and split them
    words = review_text.lower().split()
    #
    # 4. Optionally remove stop words (false by default)
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    #
    # 5. Return a list of words
    return(words)

# %%
# Load the punkt tokenizer
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

#print(tokenizer)

# %%
# Define a function to split a review into parsed sentences
def review_to_sentences( review, tokenizer, remove_stopwords=False ):
    # Function to split a review into parsed sentences. Returns a 
    # list of sentences, where each sentence is a list of words
    #
    # 1. Use the NLTK tokenizer to split the paragraph into sentences
    raw_sentences = tokenizer.tokenize(review.strip())
    #
    # 2. Loop over each sentence
    sentences = []
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            # Otherwise, call review_to_wordlist to get a list of words
            sentences.append( review_to_wordlist( raw_sentence, \
              remove_stopwords ))
    #
    # Return the list of sentences (each sentence is a list of words,
    # so this returns a list of lists
    return sentences

# %%
sentences = []  # Initialize an empty list of sentences

print("Parsing sentences from training set: ")
for review in train["review"]:
    sentences += review_to_sentences(review, tokenizer)
# Out:
# Parsing sentences from training set:
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:273: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "http://www.happierabroad.com"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
print("Parsing sentences from unlabeled set: ")
for review in unlabeled_train["review"]:
    sentences += review_to_sentences(review, tokenizer)

#html_report_part1 = open(filename,'r').read()
#soup = BeautifulSoup(html_report_part1, "html.parser")
# Out:
# Parsing sentences from unlabeled set:
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:273: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "http://www.archive.org/details/LovefromaStranger"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "http://www.loosechangeguide.com/LooseChangeGuide.html"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3.7/genericpath.py in exists(path)
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: b'His attention to detail in his roles is well known.'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-1fdc9c2b5c56> in <module>()
#       1 print("Parsing sentences from unlabeled set: ")
#       2 for review in unlabeled_train["review"]:
# ----> 3     sentences += review_to_sentences(review, tokenizer)
#       4
#       5 #html_report_part1 = open(filename,'r').read()
#
# <ipython-input-32-2fac1e127580> in review_to_sentences(review, tokenizer, remove_stopwords)
#      13         if len(raw_sentence) > 0:
#      14             # Otherwise, call review_to_wordlist to get a list of words
# ---> 15             sentences.append( review_to_wordlist( raw_sentence,               remove_stopwords ))
#      16     #
#      17     # Return the list of sentences (each sentence is a list of words,
#
# <ipython-input-30-edff2925e1af> in review_to_wordlist(review, remove_stopwords)
#       9     #
#      10     # 1. Remove HTML
# ---> 11     review_text = BeautifulSoup(review).get_text()
#      12     #
#      13     # 2. Remove non-letters
#
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     259             is_file = False
#     260             try:
# --> 261                 is_file = os.path.exists(possible_filename)
#     262             except Exception as e:
#     263                 # This is almost certainly a problem involving
#
# /usr/lib/python3.7/genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#      21         return False
#
# KeyboardInterrupt:

# %%
# Check how many sentences we have in total - should be around 850,000+
print(len(sentences))
# Out:
# 418138

# %%
print(sentences[0])
# Out:
# ['with', 'all', 'this', 'stuff', 'going', 'down', 'at', 'the', 'moment', 'with', 'mj', 'i', 've', 'started', 'listening', 'to', 'his', 'music', 'watching', 'the', 'odd', 'documentary', 'here', 'and', 'there', 'watched', 'the', 'wiz', 'and', 'watched', 'moonwalker', 'again']

# %%
print(sentences[1])
# Out:
# ['maybe', 'i', 'just', 'want', 'to', 'get', 'a', 'certain', 'insight', 'into', 'this', 'guy', 'who', 'i', 'thought', 'was', 'really', 'cool', 'in', 'the', 'eighties', 'just', 'to', 'maybe', 'make', 'up', 'my', 'mind', 'whether', 'he', 'is', 'guilty', 'or', 'innocent']

# %% [markdown]
# # Training and Saving Your Model

# %%
# Import the built-in logging module and configure it so that Word2Vec 
# creates nice output messages
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)

# Set values for various parameters
num_features = 300    # Word vector dimensionality                      
min_word_count = 40   # Minimum word count                        
num_workers = 4       # Number of threads to run in parallel
context = 10          # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# Initialize and train the model (this will take some time)
from gensim.models import word2vec
print("Training model...")
model = word2vec.Word2Vec(sentences, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)

# If you don't plan to train the model any further, calling 
# init_sims will make the model much more memory-efficient.
model.init_sims(replace=True)

# It can be helpful to create a meaningful model name and 
# save the model for later use. You can load it later using Word2Vec.load()
model_name = "300features_40minwords_10context"
model.save(model_name)
# Out:
# 2022-03-21 09:26:13,165 : INFO : 'pattern' package not found; tag filters are not available for English
# 2022-03-21 09:26:13,178 : INFO : collecting all words and their counts
# 2022-03-21 09:26:13,183 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-03-21 09:26:13,236 : INFO : PROGRESS: at sentence #10000, processed 225803 words, keeping 17776 word types
# 2022-03-21 09:26:13,293 : INFO : PROGRESS: at sentence #20000, processed 451892 words, keeping 24948 word types
# 2022-03-21 09:26:13,354 : INFO : PROGRESS: at sentence #30000, processed 671315 words, keeping 30034 word types
# Training model...
# 2022-03-21 09:26:13,434 : INFO : PROGRESS: at sentence #40000, processed 897815 words, keeping 34348 word types
# 2022-03-21 09:26:13,497 : INFO : PROGRESS: at sentence #50000, processed 1116963 words, keeping 37761 word types
# 2022-03-21 09:26:13,558 : INFO : PROGRESS: at sentence #60000, processed 1338404 words, keeping 40723 word types
# 2022-03-21 09:26:13,621 : INFO : PROGRESS: at sentence #70000, processed 1561580 words, keeping 43333 word types
# 2022-03-21 09:26:13,689 : INFO : PROGRESS: at sentence #80000, processed 1780887 words, keeping 45714 word types
# 2022-03-21 09:26:13,762 : INFO : PROGRESS: at sentence #90000, processed 2004996 words, keeping 48135 word types
# 2022-03-21 09:26:13,823 : INFO : PROGRESS: at sentence #100000, processed 2226966 words, keeping 50207 word types
# 2022-03-21 09:26:13,880 : INFO : PROGRESS: at sentence #110000, processed 2446580 words, keeping 52081 word types
# 2022-03-21 09:26:13,944 : INFO : PROGRESS: at sentence #120000, processed 2668775 words, keeping 54119 word types
# 2022-03-21 09:26:14,006 : INFO : PROGRESS: at sentence #130000, processed 2894303 words, keeping 55847 word types
# 2022-03-21 09:26:14,070 : INFO : PROGRESS: at sentence #140000, processed 3107005 words, keeping 57346 word types
# 2022-03-21 09:26:14,136 : INFO : PROGRESS: at sentence #150000, processed 3332627 words, keeping 59055 word types
# 2022-03-21 09:26:14,202 : INFO : PROGRESS: at sentence #160000, processed 3555315 words, keeping 60617 word types
# 2022-03-21 09:26:14,270 : INFO : PROGRESS: at sentence #170000, processed 3778655 words, keeping 62077 word types
# 2022-03-21 09:26:14,335 : INFO : PROGRESS: at sentence #180000, processed 3999236 words, keeping 63496 word types
# 2022-03-21 09:26:14,395 : INFO : PROGRESS: at sentence #190000, processed 4224449 words, keeping 64794 word types
# 2022-03-21 09:26:14,461 : INFO : PROGRESS: at sentence #200000, processed 4448603 words, keeping 66087 word types
# 2022-03-21 09:26:14,522 : INFO : PROGRESS: at sentence #210000, processed 4669967 words, keeping 67390 word types
# 2022-03-21 09:26:14,584 : INFO : PROGRESS: at sentence #220000, processed 4894968 words, keeping 68697 word types
# 2022-03-21 09:26:14,651 : INFO : PROGRESS: at sentence #230000, processed 5117545 words, keeping 69958 word types
# 2022-03-21 09:26:14,711 : INFO : PROGRESS: at sentence #240000, processed 5345050 words, keeping 71167 word types
# 2022-03-21 09:26:14,770 : INFO : PROGRESS: at sentence #250000, processed 5559165 words, keeping 72351 word types
# 2022-03-21 09:26:14,834 : INFO : PROGRESS: at sentence #260000, processed 5779146 words, keeping 73478 word types
# 2022-03-21 09:26:14,895 : INFO : PROGRESS: at sentence #270000, processed 6000435 words, keeping 74767 word types
# 2022-03-21 09:26:14,959 : INFO : PROGRESS: at sentence #280000, processed 6226314 words, keeping 76369 word types
# 2022-03-21 09:26:15,024 : INFO : PROGRESS: at sentence #290000, processed 6449474 words, keeping 77839 word types
# 2022-03-21 09:26:15,085 : INFO : PROGRESS: at sentence #300000, processed 6674077 words, keeping 79171 word types
# 2022-03-21 09:26:15,154 : INFO : PROGRESS: at sentence #310000, processed 6899391 words, keeping 80480 word types
# 2022-03-21 09:26:15,223 : INFO : PROGRESS: at sentence #320000, processed 7124278 words, keeping 81808 word types
# 2022-03-21 09:26:15,290 : INFO : PROGRESS: at sentence #330000, processed 7346021 words, keeping 83030 word types
# 2022-03-21 09:26:15,357 : INFO : PROGRESS: at sentence #340000, processed 7575533 words, keeping 84280 word types
# 2022-03-21 09:26:15,423 : INFO : PROGRESS: at sentence #350000, processed 7798803 words, keeping 85425 word types
# 2022-03-21 09:26:15,495 : INFO : PROGRESS: at sentence #360000, processed 8019427 words, keeping 86596 word types
# 2022-03-21 09:26:15,563 : INFO : PROGRESS: at sentence #370000, processed 8246619 words, keeping 87708 word types
# 2022-03-21 09:26:15,636 : INFO : PROGRESS: at sentence #380000, processed 8471766 words, keeping 88878 word types
# 2022-03-21 09:26:15,715 : INFO : PROGRESS: at sentence #390000, processed 8701497 words, keeping 89907 word types
# 2022-03-21 09:26:15,784 : INFO : PROGRESS: at sentence #400000, processed 8924446 words, keeping 90916 word types
# 2022-03-21 09:26:15,852 : INFO : PROGRESS: at sentence #410000, processed 9145796 words, keeping 91880 word types
# 2022-03-21 09:26:15,905 : INFO : collected 92735 word types from a corpus of 9326730 raw words and 418138 sentences
# 2022-03-21 09:26:15,907 : INFO : Loading a fresh vocabulary
# 2022-03-21 09:26:15,975 : INFO : effective_min_count=40 retains 11184 unique words (12% of original 92735, drops 81551)
# 2022-03-21 09:26:15,976 : INFO : effective_min_count=40 leaves 8888220 word corpus (95% of original 9326730, drops 438510)
# 2022-03-21 09:26:16,023 : INFO : deleting the raw counts dictionary of 92735 items
# 2022-03-21 09:26:16,029 : INFO : sample=0.001 downsamples 49 most-common words
# 2022-03-21 09:26:16,031 : INFO : downsampling leaves estimated 6517041 word corpus (73.3% of prior 8888220)
# 2022-03-21 09:26:16,079 : INFO : estimated required memory for 11184 words and 300 dimensions: 32433600 bytes
# 2022-03-21 09:26:16,080 : INFO : resetting layer weights
# 2022-03-21 09:26:18,192 : INFO : training model with 4 workers on 11184 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2022-03-21 09:26:19,232 : INFO : EPOCH 1 - PROGRESS: at 7.04% examples, 447816 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:20,261 : INFO : EPOCH 1 - PROGRESS: at 14.45% examples, 457519 words/s, in_qsize 8, out_qsize 0
# 2022-03-21 09:26:21,276 : INFO : EPOCH 1 - PROGRESS: at 21.87% examples, 463295 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:22,283 : INFO : EPOCH 1 - PROGRESS: at 29.40% examples, 468856 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:23,309 : INFO : EPOCH 1 - PROGRESS: at 37.08% examples, 471782 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:24,316 : INFO : EPOCH 1 - PROGRESS: at 44.16% examples, 469552 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:25,319 : INFO : EPOCH 1 - PROGRESS: at 51.65% examples, 472011 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:26,325 : INFO : EPOCH 1 - PROGRESS: at 58.83% examples, 471096 words/s, in_qsize 4, out_qsize 3
# 2022-03-21 09:26:27,349 : INFO : EPOCH 1 - PROGRESS: at 66.46% examples, 472443 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:28,365 : INFO : EPOCH 1 - PROGRESS: at 73.81% examples, 472517 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:29,397 : INFO : EPOCH 1 - PROGRESS: at 81.01% examples, 471274 words/s, in_qsize 6, out_qsize 1
# 2022-03-21 09:26:30,425 : INFO : EPOCH 1 - PROGRESS: at 88.37% examples, 470981 words/s, in_qsize 6, out_qsize 1
# 2022-03-21 09:26:31,460 : INFO : EPOCH 1 - PROGRESS: at 95.44% examples, 469412 words/s, in_qsize 6, out_qsize 1
# 2022-03-21 09:26:32,042 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-03-21 09:26:32,049 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-21 09:26:32,052 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-21 09:26:32,055 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-21 09:26:32,058 : INFO : EPOCH - 1 : training on 9326730 raw words (6517436 effective words) took 13.9s, 470386 effective words/s
# 2022-03-21 09:26:33,100 : INFO : EPOCH 2 - PROGRESS: at 7.04% examples, 448524 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:34,102 : INFO : EPOCH 2 - PROGRESS: at 14.01% examples, 449970 words/s, in_qsize 6, out_qsize 1
# 2022-03-21 09:26:35,174 : INFO : EPOCH 2 - PROGRESS: at 19.40% examples, 407202 words/s, in_qsize 7, out_qsize 1
# 2022-03-21 09:26:36,202 : INFO : EPOCH 2 - PROGRESS: at 24.90% examples, 392171 words/s, in_qsize 7, out_qsize 1
# 2022-03-21 09:26:37,211 : INFO : EPOCH 2 - PROGRESS: at 31.18% examples, 394067 words/s, in_qsize 5, out_qsize 2
# 2022-03-21 09:26:38,231 : INFO : EPOCH 2 - PROGRESS: at 38.46% examples, 405757 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:39,238 : INFO : EPOCH 2 - PROGRESS: at 45.52% examples, 413174 words/s, in_qsize 8, out_qsize 1
# 2022-03-21 09:26:40,248 : INFO : EPOCH 2 - PROGRESS: at 52.78% examples, 420149 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:41,268 : INFO : EPOCH 2 - PROGRESS: at 60.16% examples, 425139 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:42,273 : INFO : EPOCH 2 - PROGRESS: at 67.53% examples, 430559 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:43,306 : INFO : EPOCH 2 - PROGRESS: at 74.55% examples, 431724 words/s, in_qsize 6, out_qsize 1
# 2022-03-21 09:26:44,335 : INFO : EPOCH 2 - PROGRESS: at 81.96% examples, 435253 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:45,344 : INFO : EPOCH 2 - PROGRESS: at 88.99% examples, 436728 words/s, in_qsize 5, out_qsize 2
# 2022-03-21 09:26:46,366 : INFO : EPOCH 2 - PROGRESS: at 95.66% examples, 436222 words/s, in_qsize 5, out_qsize 2
# 2022-03-21 09:26:46,940 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-03-21 09:26:46,942 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-21 09:26:46,948 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-21 09:26:46,951 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-21 09:26:46,952 : INFO : EPOCH - 2 : training on 9326730 raw words (6515912 effective words) took 14.9s, 437873 effective words/s
# 2022-03-21 09:26:47,985 : INFO : EPOCH 3 - PROGRESS: at 7.05% examples, 452241 words/s, in_qsize 5, out_qsize 2
# 2022-03-21 09:26:48,987 : INFO : EPOCH 3 - PROGRESS: at 14.45% examples, 465989 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:50,007 : INFO : EPOCH 3 - PROGRESS: at 21.76% examples, 465821 words/s, in_qsize 6, out_qsize 1
# 2022-03-21 09:26:51,013 : INFO : EPOCH 3 - PROGRESS: at 28.98% examples, 465767 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:52,032 : INFO : EPOCH 3 - PROGRESS: at 36.43% examples, 467188 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:53,048 : INFO : EPOCH 3 - PROGRESS: at 43.73% examples, 467257 words/s, in_qsize 6, out_qsize 1
# 2022-03-21 09:26:54,083 : INFO : EPOCH 3 - PROGRESS: at 51.31% examples, 468892 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:55,114 : INFO : EPOCH 3 - PROGRESS: at 59.04% examples, 471245 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:56,115 : INFO : EPOCH 3 - PROGRESS: at 66.68% examples, 473760 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:57,118 : INFO : EPOCH 3 - PROGRESS: at 73.70% examples, 472259 words/s, in_qsize 8, out_qsize 1
# 2022-03-21 09:26:58,124 : INFO : EPOCH 3 - PROGRESS: at 81.11% examples, 473364 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:26:59,131 : INFO : EPOCH 3 - PROGRESS: at 88.47% examples, 473687 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:00,131 : INFO : EPOCH 3 - PROGRESS: at 95.66% examples, 473706 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:00,739 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-03-21 09:27:00,749 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-21 09:27:00,761 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-21 09:27:00,773 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-21 09:27:00,774 : INFO : EPOCH - 3 : training on 9326730 raw words (6517262 effective words) took 13.8s, 471954 effective words/s
# 2022-03-21 09:27:01,796 : INFO : EPOCH 4 - PROGRESS: at 6.94% examples, 450264 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:02,806 : INFO : EPOCH 4 - PROGRESS: at 14.45% examples, 466763 words/s, in_qsize 8, out_qsize 1
# 2022-03-21 09:27:03,844 : INFO : EPOCH 4 - PROGRESS: at 21.76% examples, 463663 words/s, in_qsize 8, out_qsize 2
# 2022-03-21 09:27:04,847 : INFO : EPOCH 4 - PROGRESS: at 29.19% examples, 468040 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:05,863 : INFO : EPOCH 4 - PROGRESS: at 36.55% examples, 467907 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:06,887 : INFO : EPOCH 4 - PROGRESS: at 43.94% examples, 468401 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:07,908 : INFO : EPOCH 4 - PROGRESS: at 51.43% examples, 469783 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:08,924 : INFO : EPOCH 4 - PROGRESS: at 58.94% examples, 471228 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:09,928 : INFO : EPOCH 4 - PROGRESS: at 66.35% examples, 472053 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:10,937 : INFO : EPOCH 4 - PROGRESS: at 73.60% examples, 471854 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:11,951 : INFO : EPOCH 4 - PROGRESS: at 80.90% examples, 472025 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:12,973 : INFO : EPOCH 4 - PROGRESS: at 88.37% examples, 472621 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:14,006 : INFO : EPOCH 4 - PROGRESS: at 95.66% examples, 471887 words/s, in_qsize 8, out_qsize 2
# 2022-03-21 09:27:14,546 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-03-21 09:27:14,548 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-21 09:27:14,554 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-21 09:27:14,570 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-21 09:27:14,572 : INFO : EPOCH - 4 : training on 9326730 raw words (6517460 effective words) took 13.8s, 472859 effective words/s
# 2022-03-21 09:27:15,589 : INFO : EPOCH 5 - PROGRESS: at 7.15% examples, 463520 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:16,605 : INFO : EPOCH 5 - PROGRESS: at 14.34% examples, 461855 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:17,615 : INFO : EPOCH 5 - PROGRESS: at 21.98% examples, 471351 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:18,616 : INFO : EPOCH 5 - PROGRESS: at 29.39% examples, 474039 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:19,632 : INFO : EPOCH 5 - PROGRESS: at 35.99% examples, 462940 words/s, in_qsize 8, out_qsize 0
# 2022-03-21 09:27:20,651 : INFO : EPOCH 5 - PROGRESS: at 40.62% examples, 434740 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:21,673 : INFO : EPOCH 5 - PROGRESS: at 45.31% examples, 415505 words/s, in_qsize 8, out_qsize 1
# 2022-03-21 09:27:22,675 : INFO : EPOCH 5 - PROGRESS: at 49.61% examples, 398517 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:23,676 : INFO : EPOCH 5 - PROGRESS: at 54.83% examples, 392200 words/s, in_qsize 8, out_qsize 0
# 2022-03-21 09:27:24,693 : INFO : EPOCH 5 - PROGRESS: at 59.94% examples, 385164 words/s, in_qsize 6, out_qsize 1
# 2022-03-21 09:27:25,732 : INFO : EPOCH 5 - PROGRESS: at 65.21% examples, 379895 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:26,736 : INFO : EPOCH 5 - PROGRESS: at 70.20% examples, 375405 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:27,755 : INFO : EPOCH 5 - PROGRESS: at 75.44% examples, 372302 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:28,809 : INFO : EPOCH 5 - PROGRESS: at 80.70% examples, 369176 words/s, in_qsize 4, out_qsize 3
# 2022-03-21 09:27:29,825 : INFO : EPOCH 5 - PROGRESS: at 84.54% examples, 361053 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:30,843 : INFO : EPOCH 5 - PROGRESS: at 91.54% examples, 366661 words/s, in_qsize 7, out_qsize 0
# 2022-03-21 09:27:31,864 : INFO : EPOCH 5 - PROGRESS: at 98.47% examples, 371351 words/s, in_qsize 7, out_qsize 1
# 2022-03-21 09:27:32,014 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-03-21 09:27:32,016 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-21 09:27:32,024 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-21 09:27:32,032 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-21 09:27:32,033 : INFO : EPOCH - 5 : training on 9326730 raw words (6514814 effective words) took 17.5s, 373289 effective words/s
# 2022-03-21 09:27:32,035 : INFO : training on a 46633650 raw words (32582884 effective words) took 73.8s, 441254 effective words/s
# 2022-03-21 09:27:32,036 : INFO : precomputing L2-norms of word weight vectors
# 2022-03-21 09:27:32,140 : INFO : saving Word2Vec object under 300features_40minwords_10context, separately None
# 2022-03-21 09:27:32,141 : INFO : not storing attribute vectors_norm
# 2022-03-21 09:27:32,143 : INFO : not storing attribute cum_table
# 2022-03-21 09:27:33,161 : INFO : saved 300features_40minwords_10context

# %% [markdown]
# # Exploring the Model Results

# %%
model.doesnt_match("man woman child kitchen".split())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'kitchen'

# %%
model.doesnt_match("france england germany berlin".split())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'berlin'

# %%
model.doesnt_match("paris berlin london austria".split())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# 2022-03-21 09:27:33,239 : WARNING : vectors for words {'austria'} are not present in the model, ignoring these words
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'paris'

# %%
model.most_similar("man")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('woman', 0.6748071312904358),
#  ('lady', 0.6236153244972229),
#  ('boy', 0.5650922060012817),
#  ('soldier', 0.5586721897125244),
#  ('doctor', 0.5467119216918945),
#  ('priest', 0.5283178091049194),
#  ('farmer', 0.5251932144165039),
#  ('person', 0.5213613510131836),
#  ('monk', 0.5170087814331055),
#  ('scientist', 0.5134082436561584)]

# %%
model.most_similar("queen")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('bride', 0.7287639379501343),
#  ('princess', 0.7178443670272827),
#  ('femme', 0.6983948945999146),
#  ('victoria', 0.6855283975601196),
#  ('fatale', 0.6737505197525024),
#  ('widow', 0.6579203605651855),
#  ('mistress', 0.6476467847824097),
#  ('maid', 0.6470326781272888),
#  ('aunt', 0.6461896896362305),
#  ('barbara', 0.6380726099014282)]

# %%
model.most_similar("awful")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('terrible', 0.8036894798278809),
#  ('horrible', 0.7633634805679321),
#  ('atrocious', 0.7068098783493042),
#  ('dreadful', 0.7055938839912415),
#  ('horrendous', 0.691649317741394),
#  ('laughable', 0.6852240562438965),
#  ('abysmal', 0.670864999294281),
#  ('horrid', 0.6621063947677612),
#  ('appalling', 0.6503903865814209),
#  ('bad', 0.6488935351371765)]
